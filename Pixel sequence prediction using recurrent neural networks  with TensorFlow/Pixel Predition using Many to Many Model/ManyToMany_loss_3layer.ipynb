# %% [markdown]
# # Task2: Many to Many Models: 3_layer
# Here we predict the next pixel for each pixel in the images and calculate the cross entropy of each singular pixel against what the ground truth. Then the loss is summed up for every pixel. Note that there is only ground truth matches for the first 783 pixel predictions since the last output will be out of the input comparison range.
#
# The GRU cell is used as from task one it appeared to be more stable and give more accurate results.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
import os
import pdb

# %%
# Need to load the MNist data to work with
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/MNIST/", one_hot=True)
# one hot true gives the y labels as vectors with 1's which correspond to the number it is
# Out:
# Extracting data/MNIST/train-images-idx3-ubyte.gz
# Extracting data/MNIST/train-labels-idx1-ubyte.gz
# Extracting data/MNIST/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST/t10k-labels-idx1-ubyte.gz

# %%
n_classes = 10 # number of digits
batch_size = 100
chunk_size = 1 # feeding in pixel by pixel
n_chunks = 784 # number of pixels
rnn_size = 32
learning_rate = 0.001

# Placeholders to store the data. This shape is used to match the tf rnn cell input
x = tf.placeholder('float', [None, n_chunks,chunk_size],name='InputData')
y = tf.placeholder('float',name='LabelData')

# The ground truth of the pixels 2 to end to compare against predicted
true_pixels = tf.reshape(x, [-1,n_chunks])
true_pixels = true_pixels[:,1:]



logs_path = '/tmp/tensorflow_logs/example'

# %% [markdown]
# Define the varibles that will be used in to transform the 32d layer to 1d.

# %%
weights = tf.Variable(tf.random_normal([rnn_size,1]))
biases=tf.Variable(tf.random_normal([1]))

# %%
# Here the gru cell is defined of specified size
gru_cell = tf.nn.rnn_cell.GRUCell(rnn_size)

# Make the rnn cell 3 layers deep
gru_cell = tf.nn.rnn_cell.MultiRNNCell(cells=[gru_cell] * 3, state_is_tuple=True)

# The ouputs are a tensor of all the ouput states of the pixels
outputs, states = tf.nn.dynamic_rnn(cell = gru_cell, inputs = x,dtype=tf.float32)

# check the shape
print(outputs.get_shape())
# Out:
# (?, 784, 32)

# %%
# Outputs are reshaped in order to have in (batch*784,RNN_size) for easy matrix multiplication.
outputs = tf.reshape(outputs, [-1,rnn_size])

# linear transformation
linear = tf.matmul(outputs,weights) + biases

# Need to reshape so that we have (batch_size, num_pixels)
pixel_pred = tf.reshape(linear,[-1,n_chunks])

# Since the output is a prediction for the next state, the first 783 is taken since that is the number of GT pixels 
# available for comparisson
pixel_pred = pixel_pred[:,:-1]

# %%
# Using the tf function to calculate the Xent to avoid numerical underflow, it applies a sigmoid layer before 
# calculating the loss.
loss =  tf.nn.sigmoid_cross_entropy_with_logits(pixel_pred,true_pixels)

# Sum up the loss from each pixel to get the loss of an image
loss = tf.reduce_sum(loss,1)

# See the sum of the loss rather than the mean
loss_test = tf.reduce_sum(loss)

# Get the mean image cost and optimize over that.
cost = tf.reduce_mean(loss)
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
# Need to save the model, weights and biases varibles
saver = tf.train.Saver(write_version = tf.train.SaverDef.V2)

# Suggested Directory to use
save_MDir = 'models/Task2/gru3_layer'


#create the directory if it does not exist already
if not os.path.exists(save_MDir):
    os.makedirs(save_MDir)

#save_model = os.path.join(save_MDir,'best_accuracy_second')
save_model = os.path.join(save_MDir,'best_accuracy3')

# %% [markdown]
# ## Binarize function

# %%
def binarize(images, threshold=0.1):
    return (threshold < images).astype("float32")

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# Create a summary to monitor cost tensor
#tf.summary.scalar("loss", cost)
# Create a summary to monitor accuracy tensor
#tf.summary.scalar("accuracy", accuracy)
# Merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()

# %%
# Need to save the model, weights and biases varibles
saver2 = tf.train.Saver()

# Suggested Directory to use
save2_MDir = 'models/Task2/gru3_layer/best'


#create the directory if it does not exist already
if not os.path.exists(save2_MDir):
    os.makedirs(save2_MDir)

#save_model2 = os.path.join(save2_MDir,'best_accuracy_second')
save_model2 = os.path.join(save2_MDir,'best_accuracy_3')

# %% [markdown]
# ### Optimizer function
# Here the main work is done. Each batch is passed through and outputs the cost at the end of each epoch.

# %%
def optimize(hm_epochs, start_epoch):
    with tf.Session() as sess:
        sess.run(init)    
        count = 0
        cost_list=[]        
        start_epoch_t = time.time()
        freq_epoch = hm_epochs/5
        # For each epoch loop over all batches and optimize the cost and produce the test cost
        for epoch in range(hm_epochs):
            print("-------Running Epoch:{}-------".format(epoch+1+start_epoch))
            epoch_loss = 0
            
            start = time.time()
            n_batches = int(mnist.train.num_examples/batch_size)
            #n_batches = 10
            # print batch test and train costs.
            freq = int(n_batches/2)
            
            # Loop over all batches here
            for i in range(n_batches):
                # Get the batches ready and into the correct form and shape
                epoch_x, epoch_y = mnist.train.next_batch(batch_size)
                epoch_x = binarize(epoch_x)
                epoch_x = epoch_x.reshape((batch_size,n_chunks,chunk_size))


                _, c = sess.run([optimizer, cost], feed_dict={x: epoch_x, y: epoch_y})
                
                epoch_loss += c
                if i% freq ==0 or i == (n_batches):
                    
                    print("Trained {} batches with current epoch cost: {}".format(i+1,epoch_loss))
                    print("Last batch average cost: ", c)
                    print("Current run time is: {} \n".format(time.time()-start_epoch_t))
                    
            if epoch % freq_epoch==0:
                e_loss,e_cost = sess.run([loss_test,cost],feed_dict = {x: binarize(mnist.test.images.reshape((-1, 784, 1))), y: mnist.test.labels})
                cost_list.append(e_cost)
                
                print('Epoch', start_epoch+epoch+1, 'completed out of:',hm_epochs+start_epoch,', Current Test total loss is :',e_loss,' with average',e_cost, ', time:', time.time()-start,'\n')
                print("Total time taken for current epoch : {:f} \n".format(time.time()-start))
                # if the min cost is found then save the model to see if it is much smaller than later epochs.
                if cost_list[count]== min(cost_list):
                        saver2.save(sess= sess, save_path = save_model2)
                        print(cost_list)
                
                count = count+1
                        
        
        Final_cost_test = sess.run(cost,feed_dict = {x: binarize(mnist.test.images.reshape((-1, 784, 1))), y: mnist.test.labels})
    
        
        saver.save(sess= sess, save_path = save_model)
        
        print("At final epoch: {}, the is cost {}".format(start_epoch+epoch+1, Final_cost_test))
    print("Total time taken for run : {:f}".format(time.time()-start_epoch_t))

# %%
#optimize(30,0)
# Out:
# -------Running Epoch:1-------
# Trained 1 batches with current epoch cost: 546.7645263671875
# Last batch average cost:  546.765
# Current run time is: 1.0379581451416016
#
# Trained 276 batches with current epoch cost: 55796.713287353516
# Last batch average cost:  118.908
# Current run time is: 218.4333508014679
#
# Epoch 1 completed out of: 30 , Current Test loss: 95.8565 , time: 474.20103311538696
#
# Total time taken for current epoch : 474.207551
#
# [95.856506]
# -------Running Epoch:2-------
# Trained 1 batches with current epoch cost: 94.27005004882812
# Last batch average cost:  94.2701
# Current run time is: 476.6199367046356
#
# Trained 276 batches with current epoch cost: 24486.080757141113
# Last batch average cost:  83.1002
# Current run time is: 698.0438075065613
#
# Epoch 2 completed out of: 30 , Current Test loss: 82.1284 , time: 482.241902589798
#
# Total time taken for current epoch : 482.242404
#
# [95.856506, 82.12841]
# -------Running Epoch:3-------
# Trained 1 batches with current epoch cost: 84.77679443359375
# Last batch average cost:  84.7768
# Current run time is: 960.3713836669922
#
# Trained 276 batches with current epoch cost: 22555.998596191406
# Last batch average cost:  82.0081
# Current run time is: 1187.0600023269653
#
# Epoch 3 completed out of: 30 , Current Test loss: 79.1804 , time: 491.199853181839
#
# Total time taken for current epoch : 491.200355
#
# [95.856506, 82.12841, 79.180428]
# -------Running Epoch:4-------
# Trained 1 batches with current epoch cost: 73.64437866210938
# Last batch average cost:  73.6444
# Current run time is: 1452.7725195884705
#
# Trained 276 batches with current epoch cost: 21924.882011413574
# Last batch average cost:  82.2064
# Current run time is: 1683.4041094779968
#
# Epoch 4 completed out of: 30 , Current Test loss: 77.5599 , time: 494.16346311569214
#
# Total time taken for current epoch : 494.163463
#
# [95.856506, 82.12841, 79.180428, 77.559875]
# -------Running Epoch:5-------
# Trained 1 batches with current epoch cost: 78.10467529296875
# Last batch average cost:  78.1047
# Current run time is: 1948.015221118927
#
# Trained 276 batches with current epoch cost: 21429.26968383789
# Last batch average cost:  71.5473
# Current run time is: 2176.108785867691
#
# Epoch 5 completed out of: 30 , Current Test loss: 76.3344 , time: 491.74235582351685
#
# Total time taken for current epoch : 491.742857
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366]
# -------Running Epoch:6-------
# Trained 1 batches with current epoch cost: 77.20036315917969
# Last batch average cost:  77.2004
# Current run time is: 2440.889373779297
#
# Trained 276 batches with current epoch cost: 21224.601844787598
# Last batch average cost:  79.574
# Current run time is: 2668.7510232925415
#
# Epoch 6 completed out of: 30 , Current Test loss: 75.2264 , time: 492.2803490161896
#
# Total time taken for current epoch : 492.280851
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641]
# -------Running Epoch:7-------
# Trained 1 batches with current epoch cost: 78.99795532226562
# Last batch average cost:  78.998
# Current run time is: 2934.1449489593506
#
# Trained 276 batches with current epoch cost: 20961.57593536377
# Last batch average cost:  73.5024
# Current run time is: 3164.1099178791046
#
# Epoch 7 completed out of: 30 , Current Test loss: 74.4624 , time: 497.52635383605957
#
# Total time taken for current epoch : 497.526855
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372]
# -------Running Epoch:8-------
# Trained 1 batches with current epoch cost: 80.98635864257812
# Last batch average cost:  80.9864
# Current run time is: 3432.6868550777435
#
# Trained 276 batches with current epoch cost: 20713.540893554688
# Last batch average cost:  75.7973
# Current run time is: 3663.2657675743103
#
# Epoch 8 completed out of: 30 , Current Test loss: 73.7334 , time: 498.02311968803406
#
# Total time taken for current epoch : 498.023621
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376]
# -------Running Epoch:9-------
# Trained 1 batches with current epoch cost: 74.35553741455078
# Last batch average cost:  74.3555
# Current run time is: 3931.8731536865234
#
# Trained 276 batches with current epoch cost: 20508.830436706543
# Last batch average cost:  72.3564
# Current run time is: 4164.370987415314
#
# Epoch 9 completed out of: 30 , Current Test loss: 73.2625 , time: 501.7132246494293
#
# Total time taken for current epoch : 501.713726
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527]
# -------Running Epoch:10-------
# Trained 1 batches with current epoch cost: 74.89266967773438
# Last batch average cost:  74.8927
# Current run time is: 4434.59912610054
#
# Trained 276 batches with current epoch cost: 20340.421073913574
# Last batch average cost:  72.631
# Current run time is: 4668.398544549942
#
# Epoch 10 completed out of: 30 , Current Test loss: 72.5512 , time: 505.66925406455994
#
# Total time taken for current epoch : 505.669755
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216]
# -------Running Epoch:11-------
# Trained 1 batches with current epoch cost: 73.00776672363281
# Last batch average cost:  73.0078
# Current run time is: 4941.278251886368
#
# Trained 276 batches with current epoch cost: 20154.337364196777
# Last batch average cost:  75.5777
# Current run time is: 5178.645193815231
#
# Epoch 11 completed out of: 30 , Current Test loss: 71.9723 , time: 510.5309386253357
#
# Total time taken for current epoch : 510.531440
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328]
# -------Running Epoch:12-------
# Trained 1 batches with current epoch cost: 71.0580825805664
# Last batch average cost:  71.0581
# Current run time is: 5452.790773391724
#
# Trained 276 batches with current epoch cost: 20127.88079071045
# Last batch average cost:  72.0664
# Current run time is: 5693.445508003235
#
# Epoch 12 completed out of: 30 , Current Test loss: 71.6215 , time: 516.8188071250916
#
# Total time taken for current epoch : 516.819309
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149]
# -------Running Epoch:13-------
# Trained 1 batches with current epoch cost: 71.03581237792969
# Last batch average cost:  71.0358
# Current run time is: 5970.638956308365
#
# Trained 276 batches with current epoch cost: 19931.837799072266
# Last batch average cost:  74.73
# Current run time is: 6214.565579652786
#
# Epoch 13 completed out of: 30 , Current Test loss: 71.5894 , time: 523.3593430519104
#
# Total time taken for current epoch : 523.359845
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424]
# -------Running Epoch:14-------
# Trained 1 batches with current epoch cost: 73.28331756591797
# Last batch average cost:  73.2833
# Current run time is: 6495.213634490967
#
# Trained 276 batches with current epoch cost: 19866.40087890625
# Last batch average cost:  73.3343
# Current run time is: 6742.020409822464
#
# Epoch 14 completed out of: 30 , Current Test loss: 71.2468 , time: 532.2502496242523
#
# Total time taken for current epoch : 532.250751
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811]
# -------Running Epoch:15-------
# Trained 1 batches with current epoch cost: 71.4338607788086
# Last batch average cost:  71.4339
# Current run time is: 7028.401129245758
#
# Trained 276 batches with current epoch cost: 19797.12168121338
# Last batch average cost:  70.2251
# Current run time is: 7277.805827856064
#
# Epoch 15 completed out of: 30 , Current Test loss: 70.6446 , time: 536.1785473823547
#
# Total time taken for current epoch : 536.179049
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569]
# -------Running Epoch:16-------
# Trained 1 batches with current epoch cost: 71.44003295898438
# Last batch average cost:  71.44
# Current run time is: 7565.8238162994385
#
# Trained 276 batches with current epoch cost: 19715.42544555664
# Last batch average cost:  71.7575
# Current run time is: 7817.878179550171
#
# Epoch 16 completed out of: 30 , Current Test loss: 70.6467 , time: 541.2203116416931
#
# Total time taken for current epoch : 541.220813
#
# -------Running Epoch:17-------
# Trained 1 batches with current epoch cost: 72.8017807006836
# Last batch average cost:  72.8018
# Current run time is: 8106.895726680756
#
# Trained 276 batches with current epoch cost: 19628.69814300537
# Last batch average cost:  73.011
# Current run time is: 8363.519155025482
#
# Epoch 17 completed out of: 30 , Current Test loss: 70.2162 , time: 551.8826813697815
#
# Total time taken for current epoch : 551.882681
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156]
# -------Running Epoch:18-------
# Trained 1 batches with current epoch cost: 71.21973419189453
# Last batch average cost:  71.2197
# Current run time is: 8659.856805086136
#
# Trained 276 batches with current epoch cost: 19524.80559539795
# Last batch average cost:  67.8936
# Current run time is: 8919.162066698074
#
# Epoch 18 completed out of: 30 , Current Test loss: 69.8385 , time: 553.8041098117828
#
# Total time taken for current epoch : 553.804611
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463]
# -------Running Epoch:19-------
# Trained 1 batches with current epoch cost: 71.54597473144531
# Last batch average cost:  71.546
# Current run time is: 9214.661692857742
#
# Trained 276 batches with current epoch cost: 19470.26261138916
# Last batch average cost:  67.5745
# Current run time is: 9477.214907884598
#
# Epoch 19 completed out of: 30 , Current Test loss: 69.5618 , time: 561.3067750930786
#
# Total time taken for current epoch : 561.306775
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813]
# -------Running Epoch:20-------
# Trained 1 batches with current epoch cost: 72.2572250366211
# Last batch average cost:  72.2572
# Current run time is: 9777.168636083603
#
# Trained 276 batches with current epoch cost: 19392.379413604736
# Last batch average cost:  68.5142
# Current run time is: 10042.40505862236
#
# Epoch 20 completed out of: 30 , Current Test loss: 69.0392 , time: 568.5574843883514
#
# Total time taken for current epoch : 568.557986
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813, 69.039215]
# -------Running Epoch:21-------
# Trained 1 batches with current epoch cost: 68.86175537109375
# Last batch average cost:  68.8618
# Current run time is: 10346.738201141357
#
# Trained 276 batches with current epoch cost: 19238.429405212402
# Last batch average cost:  71.2147
# Current run time is: 10618.664811134338
#
# Epoch 21 completed out of: 30 , Current Test loss: 68.7409 , time: 579.7135300636292
#
# Total time taken for current epoch : 579.714033
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813, 69.039215, 68.740936]
# -------Running Epoch:22-------
# Trained 1 batches with current epoch cost: 71.58873748779297
# Last batch average cost:  71.5887
# Current run time is: 10927.584098815918
#
# Trained 276 batches with current epoch cost: 19078.71706390381
# Last batch average cost:  69.3274
# Current run time is: 11203.862196207047
#
# Epoch 22 completed out of: 30 , Current Test loss: 67.966 , time: 588.2896382808685
#
# Total time taken for current epoch : 588.290140
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813, 69.039215, 68.740936, 67.966011]
# -------Running Epoch:23-------
# Trained 1 batches with current epoch cost: 64.05584716796875
# Last batch average cost:  64.0558
# Current run time is: 11516.87481212616
#
# Trained 276 batches with current epoch cost: 18914.0248336792
# Last batch average cost:  68.5813
# Current run time is: 11795.630492925644
#
# Epoch 23 completed out of: 30 , Current Test loss: 67.5704 , time: 596.3178124427795
#
# Total time taken for current epoch : 596.318314
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813, 69.039215, 68.740936, 67.966011, 67.570442]
# -------Running Epoch:24-------
# Trained 1 batches with current epoch cost: 67.33963775634766
# Last batch average cost:  67.3396
# Current run time is: 12114.146008014679
#
# Trained 276 batches with current epoch cost: 18853.061206817627
# Last batch average cost:  70.3352
# Current run time is: 12400.06104016304
#
# Epoch 24 completed out of: 30 , Current Test loss: 67.0323 , time: 609.295392036438
#
# Total time taken for current epoch : 609.295894
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813, 69.039215, 68.740936, 67.966011, 67.570442, 67.032303]
# -------Running Epoch:25-------
# Trained 1 batches with current epoch cost: 69.57188415527344
# Last batch average cost:  69.5719
# Current run time is: 12724.54501414299
#
# Trained 276 batches with current epoch cost: 18673.177738189697
# Last batch average cost:  69.109
# Current run time is: 13018.03558063507
#
# Epoch 25 completed out of: 30 , Current Test loss: 67.1129 , time: 624.0694065093994
#
# Total time taken for current epoch : 624.069908
#
# -------Running Epoch:26-------
# Trained 1 batches with current epoch cost: 65.73307800292969
# Last batch average cost:  65.7331
# Current run time is: 13348.638452291489
#
# Trained 276 batches with current epoch cost: 18616.64079284668
# Last batch average cost:  67.9584
# Current run time is: 13644.777300357819
#
# Epoch 26 completed out of: 30 , Current Test loss: 66.3775 , time: 631.2398557662964
#
# Total time taken for current epoch : 631.240357
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813, 69.039215, 68.740936, 67.966011, 67.570442, 67.032303, 67.112915, 66.377541]
# -------Running Epoch:27-------
# Trained 1 batches with current epoch cost: 69.16393280029297
# Last batch average cost:  69.1639
# Current run time is: 13981.26582980156
#
# Trained 276 batches with current epoch cost: 18536.387996673584
# Last batch average cost:  66.7059
# Current run time is: 14287.574079751968
#
# Epoch 27 completed out of: 30 , Current Test loss: 66.2682 , time: 651.4425301551819
#
# Total time taken for current epoch : 651.443032
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813, 69.039215, 68.740936, 67.966011, 67.570442, 67.032303, 67.112915, 66.377541, 66.268173]
# -------Running Epoch:28-------
# Trained 1 batches with current epoch cost: 66.00505828857422
# Last batch average cost:  66.0051
# Current run time is: 14633.701097249985
#
# Trained 276 batches with current epoch cost: 18479.182693481445
# Last batch average cost:  66.8332
# Current run time is: 14943.471067905426
#
# Epoch 28 completed out of: 30 , Current Test loss: 66.4135 , time: 657.8771286010742
#
# Total time taken for current epoch : 657.877630
#
# -------Running Epoch:29-------
# Trained 1 batches with current epoch cost: 67.29764556884766
# Last batch average cost:  67.2976
# Current run time is: 15291.664420366287
#
# Trained 276 batches with current epoch cost: 18435.297958374023
# Last batch average cost:  66.9597
# Current run time is: 15608.16332745552
#
# Epoch 29 completed out of: 30 , Current Test loss: 66.0757 , time: 672.6182129383087
#
# Total time taken for current epoch : 672.618714
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813, 69.039215, 68.740936, 67.966011, 67.570442, 67.032303, 67.112915, 66.377541, 66.268173, 66.413475, 66.075668]
# -------Running Epoch:30-------
# Trained 1 batches with current epoch cost: 68.20002746582031
# Last batch average cost:  68.2
# Current run time is: 15965.442259788513
#
# Trained 276 batches with current epoch cost: 18371.756324768066
# Last batch average cost:  64.4892
# Current run time is: 16287.372924089432
#
# Epoch 30 completed out of: 30 , Current Test loss: 66.0387 , time: 695.3509993553162
#
# Total time taken for current epoch : 695.351501
#
# [95.856506, 82.12841, 79.180428, 77.559875, 76.334366, 75.22641, 74.462372, 73.733376, 73.262527, 72.551216, 71.972328, 71.62149, 71.589424, 71.246811, 70.644569, 70.64669, 70.216156, 69.838463, 69.561813, 69.039215, 68.740936, 67.966011, 67.570442, 67.032303, 67.112915, 66.377541, 66.268173, 66.413475, 66.075668, 66.03875]
# At final epoch: 30, the is cost 66.03874969482422
# Total time taken for run : 16704.384501

# %% [markdown]
# # Restoring model
# Here the model is restored and the values in the report match the recovered ones.

# %%
def print_cost(rnn_size,epochs):
    

    cost_train_list = []
    cost_test_list =[]
    b_size = 1000
    num_train = len(mnist.train.labels)
    num_test = len(mnist.test.labels)
    n_batches = num_train/b_size
    count = 0
    i = 0
    num_train = len(mnist.train.labels[:10000,:])    
    n_batches = num_train/b_size    
    start = time.time()
    while i < num_train:
        print('Processing batch number {} of {}.'.format(count+1,n_batches))
        # The ending index for the next batch is denoted j.
        j = min(i + b_size, num_train)
        
        if j<= num_test:
            
            # Get the images from the test-set between index i and j.
            images_test = mnist.test.images.reshape((-1, 784, 1))[i:j, :]

            # Get the associated labels.
            labels_test = mnist.test.labels[i:j, :]

            cost_test = sess.run(cost,feed_dict = {x: binarize(images_test), y: labels_test})
        
            cost_test_list.append(cost_test)
        images_train = mnist.train.images.reshape((-1, 784, 1))[i:j, :]

        # Get the associated labels.
        labels_test = mnist.train.labels[i:j, :]

        cost_train = sess.run(cost,feed_dict = {x: binarize(images_train), y: labels_test})
        cost_train_list.append(cost_train)
        i = j
        count +=1
    
    total_cost_train = sum(cost_train_list)/len(cost_train_list)
    total_cost_test = sum(cost_test_list)/len(cost_test_list)
    
    print(time.time()-start)
    
    print('The training cost for the 3 layer {} unit GRU many to many model is {} after {} epochs \n'.format(rnn_size,total_cost_train,epochs))
    
    print('The test cost for the 3 layer {} unit GRU many to many model is {} after {} epochs \n'.format(rnn_size,total_cost_test,epochs))

# %%
save_MDir = 'models/Task2/gru3_layer'
save_model = os.path.join(save_MDir,'best_accuracy3')
init = tf.global_variables_initializer()

# %%
sess= tf.Session()
sess.run(init)
saver2restore = tf.train.Saver()
saver2restore.restore(sess = sess, save_path= save_model)

# %%
print_cost(rnn_size=32, epochs = 30)
sess.close()
# Out:
# Processing batch number 1 of 55.0.
# Processing batch number 2 of 55.0.
# Processing batch number 3 of 55.0.
# Processing batch number 4 of 55.0.
# Processing batch number 5 of 55.0.
# Processing batch number 6 of 55.0.
# Processing batch number 7 of 55.0.
# Processing batch number 8 of 55.0.
# Processing batch number 9 of 55.0.
# Processing batch number 10 of 55.0.
# Processing batch number 11 of 55.0.
# Processing batch number 12 of 55.0.
# Processing batch number 13 of 55.0.
# Processing batch number 14 of 55.0.
# Processing batch number 15 of 55.0.
# Processing batch number 16 of 55.0.
# Processing batch number 17 of 55.0.
# Processing batch number 18 of 55.0.
# Processing batch number 19 of 55.0.
# Processing batch number 20 of 55.0.
# Processing batch number 21 of 55.0.
# Processing batch number 22 of 55.0.
# Processing batch number 23 of 55.0.
# Processing batch number 24 of 55.0.
# Processing batch number 25 of 55.0.
# Processing batch number 26 of 55.0.
# Processing batch number 27 of 55.0.
# Processing batch number 28 of 55.0.
# Processing batch number 29 of 55.0.
# Processing batch number 30 of 55.0.
# Processing batch number 31 of 55.0.
# Processing batch number 32 of 55.0.
# Processing batch number 33 of 55.0.
# Processing batch number 34 of 55.0.
# Processing batch number 35 of 55.0.
# Processing batch number 36 of 55.0.
# Processing batch number 37 of 55.0.
# Processing batch number 38 of 55.0.
# Processing batch number 39 of 55.0.
# Processing batch number 40 of 55.0.
# Processing batch number 41 of 55.0.
# Processing batch number 42 of 55.0.
# Processing batch number 43 of 55.0.
# Processing batch number 44 of 55.0.
# Processing batch number 45 of 55.0.
# Processing batch number 46 of 55.0.
# Processing batch number 47 of 55.0.
# Processing batch number 48 of 55.0.
# Processing batch number 49 of 55.0.
# Processing batch number 50 of 55.0.
# Processing batch number 51 of 55.0.
# Processing batch number 52 of 55.0.
# Processing batch number 53 of 55.0.
# Processing batch number 54 of 55.0.
# Processing batch number 55 of 55.0.
# 168.313622713089
# The training cost for the 3 layer 32 unit GRU many to many model is 66.62403065074574 after 30 epochs
#
# The test cost for the 3 layer 32 unit GRU many to many model is 66.0387451171875 after 30 epochs

# %%
print_cost(rnn_size=32, epochs = 30)
sess.close()
# Out:
# Processing batch number 1 of 10.0.
# Processing batch number 2 of 10.0.
# Processing batch number 3 of 10.0.
# Processing batch number 4 of 10.0.
# Processing batch number 5 of 10.0.
# Processing batch number 6 of 10.0.
# Processing batch number 7 of 10.0.
# Processing batch number 8 of 10.0.
# Processing batch number 9 of 10.0.
# Processing batch number 10 of 10.0.
# 51.15917897224426
# The training cost for the 3 layer 32 unit GRU many to many model is 66.33243942260742 after 30 epochs
#
# The test cost for the 3 layer 32 unit GRU many to many model is 66.0387451171875 after 30 epochs
