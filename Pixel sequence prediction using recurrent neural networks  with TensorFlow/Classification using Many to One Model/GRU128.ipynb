# %% [markdown]
# # Task1: Many to one Model:GRU128
# In this task we classifiy the MNSIT data set by using a RNN of different sizes and differnt cells. The binarized images are passed into the RNN cell one pixel at a time and the final output is taken. Here the output is transformed into fully connected layer of 100 units with a ReLU activation function. It
# is then passed through another linear layer of width 10 and a softmax operation is used to get the probabilites of each digit. Cross entropy loss function is used for the cost and the Adam optimizer is used to minimize this value.
#
# It was noted that the lstm cell was quite unstable and did not perform as well as the GRU cell over the same number of epochs. Many different learning rates turned out to be too small to learn anything in time or to large such that it would quite well for some time till it jumped to much and lost all accuracy.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math

import os
import pdb

# %%
# Need to load the MNist data to work with
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/MNIST/", one_hot=True)
# one hot true gives the y labels as vectors with 1's which correspond to the number it is
# Out:
# Extracting data/MNIST/train-images-idx3-ubyte.gz
# Extracting data/MNIST/train-labels-idx1-ubyte.gz
# Extracting data/MNIST/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST/t10k-labels-idx1-ubyte.gz

# %%
print('The size of the data that we will be working with:')
print('train set: {} '.format(len(mnist.train.labels)))
print('valid set: {} '.format(len(mnist.validation.labels)))
print('test set: {} '.format(len(mnist.test.labels)))
# Out:
# The size of the data that we will be working with:
# train set: 55000
# valid set: 5000
# test set: 10000

# %%
# define parameters
n_classes = 10 # digits
batch_size = 100
chunk_size = 1 # input per timestep
n_chunks = 784 # number of pixels/timesteps
rnn_size = 128
units_output = 100 # output after rnn
learning_rate = 0.001

# placeholders tp store the inputs and labels 
x = tf.placeholder('float', [None, n_chunks,chunk_size],name='InputData')
y = tf.placeholder('float',name='LabelData')

logs_path = '/tmp/tensorflow_logs/example'

# %% [markdown]
# Define the varibles that will be used in to transform the 32d layer to 100d fully connected layer.
#
# Then for the second fully connected layer from 100 to 10.

# %%
layer1 = {'weights':tf.Variable(tf.random_normal([rnn_size,units_output]),name='Weights1'),
             'biases':tf.Variable(tf.random_normal([units_output]),name='Bias')}
layer2 = {'weights':tf.Variable(tf.random_normal([units_output,n_classes]),name='Weights2'),
             'biases':tf.Variable(tf.random_normal([n_classes]),name='Bias2')}

# %%
# Here the gru cell is defined of specified size
gru_cell = tf.nn.rnn_cell.GRUCell(rnn_size)

# The ouputs are a tensor of all the ouput states of the pixels
outputs, states = tf.nn.dynamic_rnn(cell = gru_cell, inputs = x,dtype=tf.float32)

# Checking to make sure of the correct shape
print(outputs.get_shape())
# Out:
# (?, 784, 128)

# %%
# Many to one model so we need only the last output of the rnn.
outputs = outputs[:, -1, :]

# linear transformation
output_rnn = tf.matmul(outputs,layer1['weights']) + layer1['biases']

# Relu activation
act = tf.nn.relu(output_rnn)

# linear transformatino
output = tf.matmul(act,layer2['weights'])+layer2['biases']

# calculate cost of batch
Xent =  tf.nn.softmax_cross_entropy_with_logits(output,y)

# calculate the average cost per image and optimize
with tf.name_scope('Loss'):
    cost = tf.reduce_mean( Xent )
with tf.name_scope('Adam'):    
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# Calculate the accuracy by comparing the output label with the true label of the images

# %%
# create a boolean of correct labels and take the average to 
# get the percentage of correctly available
with tf.name_scope('Accuracy'):
    correct_label = tf.equal(tf.argmax(output, 1), tf.argmax(y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_label, tf.float32))

# %% [markdown]
# ### Save the models

# %%
# Need to save the model, weights and biases varibles
saver = tf.train.Saver(write_version = tf.train.SaverDef.V2)

# Suggested Directory to use
save_MDir = 'models/gru128/'


#create the directory if it does not exist already
if not os.path.exists(save_MDir):
    os.makedirs(save_MDir)

save_model = os.path.join(save_MDir,'best_accuracy_3')

# %%
# Need to save the model, weights and biases varibles
saver2 = tf.train.Saver()

# Suggested Directory to use
save2_MDir = 'models/gru128/best'


#create the directory if it does not exist already
if not os.path.exists(save2_MDir):
    os.makedirs(save2_MDir)

save_model2 = os.path.join(save2_MDir,'best_accuracy_3')

# %% [markdown]
# ### Binarize function

# %%
def binarize(images, threshold=0.1):
    return (threshold < images).astype("float32")

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# Create a summary to monitor cost tensor
tf.summary.scalar("loss", cost)
# Create a summary to monitor accuracy tensor
tf.summary.scalar("accuracy", accuracy)
# Merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()

# %% [markdown]
# ### Optimizer function
# Here the main work is done. Each batch is passed through and outputs the cost at the end of each epoch.

# %%
def optimize(hm_epochs):
    with tf.Session() as sess:
        sess.run(init)
        summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())        
        start_epoch = time.time()
        freq_epoch = hm_epochs/30
        acc_list = []
        count = 0
        # For each epoch loop over all batches and optimize the cost and produce the test cost
        for epoch in range(hm_epochs):
            print("-------Running Epoch:{}-------".format(epoch+1))
            epoch_loss = 0
            
            start = time.time()
            n_batches = int(mnist.train.num_examples/batch_size)

            # print batch test and train costs.            
            freq = int(n_batches/5)
            for i in range(n_batches):
                epoch_x, epoch_y = mnist.train.next_batch(batch_size)
                epoch_x = binarize(epoch_x)
                epoch_x = epoch_x.reshape((batch_size,n_chunks,chunk_size))


                _, c,summary = sess.run([optimizer, cost,merged_summary_op], feed_dict={x: epoch_x, y: epoch_y})
                summary_writer.add_summary(summary, epoch * n_batches + i)
                epoch_loss += c
                
                # 5 times per epoch get a rough idea of how the train and test accuracies perform on the test and train
                # batches.
                if i% freq ==0 or i == (n_batches):
                    print("Trained {} batches with current epoch cost: {}".format(i+1,epoch_loss))
                    acc_train = sess.run(accuracy,feed_dict = {x: epoch_x, y: epoch_y})
                    acc_test = accuracy.eval({x: binarize(mnist.test.images[0:batch_size].reshape((-1, 784, 1))), y: mnist.test.labels[0:batch_size]})
                    print("At batch: {0}, the training accuracy is: {1:.1%}".format(i+1, acc_train))
                    print("At batch: {0}, the test accuracy is: {1:.1%}".format(i+1, acc_test))
                    print("Current run time is: {} \n".format(time.time()-start_epoch))
            saver.save(sess= sess, save_path = save_model)  
            # At the end of the epoch calculate the accuracy
            if epoch % freq_epoch==0:
                print('Epoch', epoch+1, 'completed out of:',hm_epochs,'loss:',epoch_loss, ', time:', time.time()-start,'\n')
                acc_test = accuracy.eval({x: binarize(mnist.test.images[0:batch_size].reshape((-1, 784, 1))), y: mnist.test.labels[0:batch_size]})
                print("At end of epoch: {0}, the training accuracy on batch is: {1:.1%}".format(epoch+1, acc_train))
                print("At end of epoch: {}, the test accuracy is: {:.1%}".format(epoch+1, acc_test))
                acc_list.append(acc_test)
                
                # If the accuracy is good save model
                if epoch>=0:
                    if acc_list[count]>= 0.85:
                        saver2.save(sess= sess, save_path = save_model2)
                        print(acc_list)
                print("Total time taken for current epoch : {:f} \n".format(time.time()-start))
            count+=1
            
            
        saver.save(sess= sess, save_path = save_model)
        Final_acc_test,Final_cost_test = sess.run([accuracy,cost],feed_dict = {x: binarize(mnist.test.images.reshape((-1, 784, 1))), y: mnist.test.labels})

        print("At final epoch: {}, the test accuracy is: {:.1%}, with cost {}".format(epoch+1, Final_acc_test, Final_cost_test))
    print("Total time taken for run : {:f}".format(time.time()-start_epoch))

# %%
#optimize(30)
# Out:
# -------Running Epoch:1-------
# Trained 1 batches with current epoch cost: 12.937808990478516
# At batch: 1, the training accuracy is: 12.0%
# At batch: 1, the test accuracy is: 10.0%
# Current run time is: 3.469165086746216
#
# Trained 111 batches with current epoch cost: 325.59219563007355
# At batch: 111, the training accuracy is: 24.0%
# At batch: 111, the test accuracy is: 30.0%
# Current run time is: 226.72235083580017
#
# Trained 221 batches with current epoch cost: 523.2576617002487
# At batch: 221, the training accuracy is: 46.0%
# At batch: 221, the test accuracy is: 45.0%
# Current run time is: 433.71699142456055
#
# Trained 331 batches with current epoch cost: 702.6905467510223
# At batch: 331, the training accuracy is: 43.0%
# At batch: 331, the test accuracy is: 47.0%
# Current run time is: 643.8273236751556
#
# Trained 441 batches with current epoch cost: 872.0261687040329
# At batch: 441, the training accuracy is: 33.0%
# At batch: 441, the test accuracy is: 31.0%
# Current run time is: 854.9294986724854
#
# Epoch 1 completed out of: 30 loss: 1029.8900575 , time: 1066.059842824936
#
# At end of epoch: 1, the training accuracy on batch is: 33.0%
# At end of epoch: 1, the test accuracy is: 52.0%
# Total time taken for current epoch : 1066.908979
#
# -------Running Epoch:2-------
# Trained 1 batches with current epoch cost: 1.3454548120498657
# At batch: 1, the training accuracy is: 48.0%
# At batch: 1, the test accuracy is: 56.0%
# Current run time is: 1070.819373369217
#
# Trained 111 batches with current epoch cost: 138.4311107993126
# At batch: 111, the training accuracy is: 66.0%
# At batch: 111, the test accuracy is: 62.0%
# Current run time is: 1287.970670223236
#
# Trained 221 batches with current epoch cost: 258.4600210785866
# At batch: 221, the training accuracy is: 66.0%
# At batch: 221, the test accuracy is: 65.0%
# Current run time is: 1510.8991029262543
#
# Trained 331 batches with current epoch cost: 371.93756568431854
# At batch: 331, the training accuracy is: 68.0%
# At batch: 331, the test accuracy is: 65.0%
# Current run time is: 1738.5024626255035
#
# Trained 441 batches with current epoch cost: 484.3473227620125
# At batch: 441, the training accuracy is: 62.0%
# At batch: 441, the test accuracy is: 63.0%
# Current run time is: 1957.025419473648
#
# Epoch 2 completed out of: 30 loss: 591.04172802 , time: 1107.9763822555542
#
# At end of epoch: 2, the training accuracy on batch is: 62.0%
# At end of epoch: 2, the test accuracy is: 61.0%
# Total time taken for current epoch : 1108.894642
#
# -------Running Epoch:3-------
# Trained 1 batches with current epoch cost: 1.0357154607772827
# At batch: 1, the training accuracy is: 67.0%
# At batch: 1, the test accuracy is: 66.0%
# Current run time is: 2180.1677906513214
#
# Trained 111 batches with current epoch cost: 101.22238910198212
# At batch: 111, the training accuracy is: 70.0%
# At batch: 111, the test accuracy is: 64.0%
# Current run time is: 2410.488280057907
#
# Trained 221 batches with current epoch cost: 196.15847140550613
# At batch: 221, the training accuracy is: 71.0%
# At batch: 221, the test accuracy is: 70.0%
# Current run time is: 2672.748835325241
#
# Trained 331 batches with current epoch cost: 289.01313626766205
# At batch: 331, the training accuracy is: 74.0%
# At batch: 331, the test accuracy is: 67.0%
# Current run time is: 2932.134240627289
#
# Trained 441 batches with current epoch cost: 382.4510768055916
# At batch: 441, the training accuracy is: 69.0%
# At batch: 441, the test accuracy is: 68.0%
# Current run time is: 3185.928032398224
#
# Epoch 3 completed out of: 30 loss: 469.280123651 , time: 1245.9117736816406
#
# At end of epoch: 3, the training accuracy on batch is: 69.0%
# At end of epoch: 3, the test accuracy is: 67.0%
# Total time taken for current epoch : 1246.721863
#
# -------Running Epoch:4-------
# Trained 1 batches with current epoch cost: 1.0567505359649658
# At batch: 1, the training accuracy is: 62.0%
# At batch: 1, the test accuracy is: 67.0%
# Current run time is: 3426.526799917221
#
# Trained 111 batches with current epoch cost: 87.15228459239006
# At batch: 111, the training accuracy is: 74.0%
# At batch: 111, the test accuracy is: 68.0%
# Current run time is: 3648.5622482299805
#
# Trained 221 batches with current epoch cost: 167.83293002843857
# At batch: 221, the training accuracy is: 87.0%
# At batch: 221, the test accuracy is: 70.0%
# Current run time is: 3870.234978914261
#
# Trained 331 batches with current epoch cost: 245.76021021604538
# At batch: 331, the training accuracy is: 75.0%
# At batch: 331, the test accuracy is: 70.0%
# Current run time is: 4090.9791131019592
#
# Trained 441 batches with current epoch cost: 322.999692261219
# At batch: 441, the training accuracy is: 73.0%
# At batch: 441, the test accuracy is: 75.0%
# Current run time is: 4311.064739227295
#
# Epoch 4 completed out of: 30 loss: 396.397349715 , time: 1104.8751447200775
#
# At end of epoch: 4, the training accuracy on batch is: 73.0%
# At end of epoch: 4, the test accuracy is: 78.0%
# Total time taken for current epoch : 1105.671733
#
# -------Running Epoch:5-------
# Trained 1 batches with current epoch cost: 0.6781414747238159
# At batch: 1, the training accuracy is: 81.0%
# At batch: 1, the test accuracy is: 79.0%
# Current run time is: 4531.966822147369
#
# Trained 111 batches with current epoch cost: 73.50933787226677
# At batch: 111, the training accuracy is: 79.0%
# At batch: 111, the test accuracy is: 77.0%
# Current run time is: 4750.50924372673
#
# Trained 221 batches with current epoch cost: 144.51837921142578
# At batch: 221, the training accuracy is: 76.0%
# At batch: 221, the test accuracy is: 86.0%
# Current run time is: 4970.4221913814545
#
# Trained 331 batches with current epoch cost: 207.47444465756416
# At batch: 331, the training accuracy is: 84.0%
# At batch: 331, the test accuracy is: 82.0%
# Current run time is: 5190.871295213699
#
# Trained 441 batches with current epoch cost: 269.6321293115616
# At batch: 441, the training accuracy is: 85.0%
# At batch: 441, the test accuracy is: 81.0%
# Current run time is: 5412.5365698337555
#
# Epoch 5 completed out of: 30 loss: 331.607236445 , time: 1101.192522764206
#
# At end of epoch: 5, the training accuracy on batch is: 85.0%
# At end of epoch: 5, the test accuracy is: 80.0%
# Total time taken for current epoch : 1101.988235
#
# -------Running Epoch:6-------
# Trained 1 batches with current epoch cost: 0.4890808165073395
# At batch: 1, the training accuracy is: 86.0%
# At batch: 1, the test accuracy is: 82.0%
# Current run time is: 5633.96444940567
#
# Trained 111 batches with current epoch cost: 54.73111206293106
# At batch: 111, the training accuracy is: 88.0%
# At batch: 111, the test accuracy is: 87.0%
# Current run time is: 5854.642417192459
#
# Trained 221 batches with current epoch cost: 106.02638122439384
# At batch: 221, the training accuracy is: 83.0%
# At batch: 221, the test accuracy is: 86.0%
# Current run time is: 6075.514790296555
#
# Trained 331 batches with current epoch cost: 152.79801477491856
# At batch: 331, the training accuracy is: 80.0%
# At batch: 331, the test accuracy is: 86.0%
# Current run time is: 6296.8422203063965
#
# Trained 441 batches with current epoch cost: 200.8823869675398
# At batch: 441, the training accuracy is: 84.0%
# At batch: 441, the test accuracy is: 90.0%
# Current run time is: 6518.618509054184
#
# Epoch 6 completed out of: 30 loss: 247.044423118 , time: 1105.8723773956299
#
# At end of epoch: 6, the training accuracy on batch is: 84.0%
# At end of epoch: 6, the test accuracy is: 86.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001]
# Total time taken for current epoch : 1107.220791
#
# -------Running Epoch:7-------
# Trained 1 batches with current epoch cost: 0.2091951221227646
# At batch: 1, the training accuracy is: 92.0%
# At batch: 1, the test accuracy is: 88.0%
# Current run time is: 6741.072722196579
#
# Trained 111 batches with current epoch cost: 45.88852323591709
# At batch: 111, the training accuracy is: 92.0%
# At batch: 111, the test accuracy is: 86.0%
# Current run time is: 6961.50829744339
#
# Trained 221 batches with current epoch cost: 87.39862695336342
# At batch: 221, the training accuracy is: 89.0%
# At batch: 221, the test accuracy is: 88.0%
# Current run time is: 7182.849370479584
#
# Trained 331 batches with current epoch cost: 126.8189827799797
# At batch: 331, the training accuracy is: 87.0%
# At batch: 331, the test accuracy is: 92.0%
# Current run time is: 7404.075003623962
#
# Trained 441 batches with current epoch cost: 167.1980776041746
# At batch: 441, the training accuracy is: 96.0%
# At batch: 441, the test accuracy is: 89.0%
# Current run time is: 7626.097341775894
#
# Epoch 7 completed out of: 30 loss: 201.781866409 , time: 1107.5281252861023
#
# At end of epoch: 7, the training accuracy on batch is: 96.0%
# At end of epoch: 7, the test accuracy is: 90.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998]
# Total time taken for current epoch : 1108.881642
#
# -------Running Epoch:8-------
# Trained 1 batches with current epoch cost: 0.39689895510673523
# At batch: 1, the training accuracy is: 93.0%
# At batch: 1, the test accuracy is: 91.0%
# Current run time is: 7849.936593770981
#
# Trained 111 batches with current epoch cost: 35.3816247433424
# At batch: 111, the training accuracy is: 87.0%
# At batch: 111, the test accuracy is: 92.0%
# Current run time is: 8071.364237308502
#
# Trained 221 batches with current epoch cost: 68.00800969451666
# At batch: 221, the training accuracy is: 88.0%
# At batch: 221, the test accuracy is: 91.0%
# Current run time is: 8292.702976465225
#
# Trained 331 batches with current epoch cost: 100.54501087963581
# At batch: 331, the training accuracy is: 91.0%
# At batch: 331, the test accuracy is: 91.0%
# Current run time is: 8514.434666872025
#
# Trained 441 batches with current epoch cost: 128.9570085592568
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 93.0%
# Current run time is: 8736.456732749939
#
# Epoch 8 completed out of: 30 loss: 155.477636036 , time: 1110.9131038188934
#
# At end of epoch: 8, the training accuracy on batch is: 99.0%
# At end of epoch: 8, the test accuracy is: 95.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999]
# Total time taken for current epoch : 1112.265079
#
# -------Running Epoch:9-------
# Trained 1 batches with current epoch cost: 0.2045346051454544
# At batch: 1, the training accuracy is: 93.0%
# At batch: 1, the test accuracy is: 90.0%
# Current run time is: 8962.21372294426
#
# Trained 111 batches with current epoch cost: 27.552866987884045
# At batch: 111, the training accuracy is: 91.0%
# At batch: 111, the test accuracy is: 93.0%
# Current run time is: 9184.99880194664
#
# Trained 221 batches with current epoch cost: 53.43509792909026
# At batch: 221, the training accuracy is: 95.0%
# At batch: 221, the test accuracy is: 93.0%
# Current run time is: 9407.284051656723
#
# Trained 331 batches with current epoch cost: 78.36008093506098
# At batch: 331, the training accuracy is: 99.0%
# At batch: 331, the test accuracy is: 93.0%
# Current run time is: 9630.97007226944
#
# Trained 441 batches with current epoch cost: 104.08032297343016
# At batch: 441, the training accuracy is: 97.0%
# At batch: 441, the test accuracy is: 89.0%
# Current run time is: 9853.667162895203
#
# Epoch 9 completed out of: 30 loss: 127.608726576 , time: 1114.7965607643127
#
# At end of epoch: 9, the training accuracy on batch is: 97.0%
# At end of epoch: 9, the test accuracy is: 92.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002]
# Total time taken for current epoch : 1116.182059
#
# -------Running Epoch:10-------
# Trained 1 batches with current epoch cost: 0.2068561613559723
# At batch: 1, the training accuracy is: 95.0%
# At batch: 1, the test accuracy is: 92.0%
# Current run time is: 10078.369226694107
#
# Trained 111 batches with current epoch cost: 23.3771568313241
# At batch: 111, the training accuracy is: 90.0%
# At batch: 111, the test accuracy is: 94.0%
# Current run time is: 10300.147127628326
#
# Trained 221 batches with current epoch cost: 45.33324117958546
# At batch: 221, the training accuracy is: 98.0%
# At batch: 221, the test accuracy is: 96.0%
# Current run time is: 10522.258511781693
#
# Trained 331 batches with current epoch cost: 66.44814363867044
# At batch: 331, the training accuracy is: 94.0%
# At batch: 331, the test accuracy is: 95.0%
# Current run time is: 10745.316878080368
#
# Trained 441 batches with current epoch cost: 88.50899483263493
# At batch: 441, the training accuracy is: 94.0%
# At batch: 441, the test accuracy is: 96.0%
# Current run time is: 10968.532859563828
#
# Epoch 10 completed out of: 30 loss: 107.757603034 , time: 1114.0352823734283
#
# At end of epoch: 10, the training accuracy on batch is: 94.0%
# At end of epoch: 10, the test accuracy is: 92.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002]
# Total time taken for current epoch : 1115.378799
#
# -------Running Epoch:11-------
# Trained 1 batches with current epoch cost: 0.23869022727012634
# At batch: 1, the training accuracy is: 95.0%
# At batch: 1, the test accuracy is: 92.0%
# Current run time is: 11193.790093660355
#
# Trained 111 batches with current epoch cost: 19.398847319185734
# At batch: 111, the training accuracy is: 91.0%
# At batch: 111, the test accuracy is: 97.0%
# Current run time is: 11417.572407722473
#
# Trained 221 batches with current epoch cost: 37.36203216202557
# At batch: 221, the training accuracy is: 95.0%
# At batch: 221, the test accuracy is: 94.0%
# Current run time is: 11640.664869070053
#
# Trained 331 batches with current epoch cost: 57.3599840644747
# At batch: 331, the training accuracy is: 94.0%
# At batch: 331, the test accuracy is: 95.0%
# Current run time is: 11864.154125928879
#
# Trained 441 batches with current epoch cost: 74.8457267973572
# At batch: 441, the training accuracy is: 97.0%
# At batch: 441, the test accuracy is: 94.0%
# Current run time is: 12087.443893909454
#
# Epoch 11 completed out of: 30 loss: 91.6142292023 , time: 1117.5433571338654
#
# At end of epoch: 11, the training accuracy on batch is: 97.0%
# At end of epoch: 11, the test accuracy is: 96.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998]
# Total time taken for current epoch : 1118.873505
#
# -------Running Epoch:12-------
# Trained 1 batches with current epoch cost: 0.10353643447160721
# At batch: 1, the training accuracy is: 98.0%
# At batch: 1, the test accuracy is: 96.0%
# Current run time is: 12312.668032884598
#
# Trained 111 batches with current epoch cost: 16.02052554488182
# At batch: 111, the training accuracy is: 99.0%
# At batch: 111, the test accuracy is: 95.0%
# Current run time is: 12536.220124483109
#
# Trained 221 batches with current epoch cost: 33.72475605458021
# At batch: 221, the training accuracy is: 96.0%
# At batch: 221, the test accuracy is: 96.0%
# Current run time is: 12760.892620801926
#
# Trained 331 batches with current epoch cost: 53.12489516660571
# At batch: 331, the training accuracy is: 98.0%
# At batch: 331, the test accuracy is: 93.0%
# Current run time is: 12984.014027833939
#
# Trained 441 batches with current epoch cost: 69.34467847459018
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 94.0%
# Current run time is: 13208.056022405624
#
# Epoch 12 completed out of: 30 loss: 84.6242313078 , time: 1119.7725298404694
#
# At end of epoch: 12, the training accuracy on batch is: 99.0%
# At end of epoch: 12, the test accuracy is: 95.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999]
# Total time taken for current epoch : 1121.107889
#
# -------Running Epoch:13-------
# Trained 1 batches with current epoch cost: 0.14449924230575562
# At batch: 1, the training accuracy is: 98.0%
# At batch: 1, the test accuracy is: 95.0%
# Current run time is: 13433.741769075394
#
# Trained 111 batches with current epoch cost: 13.86268544010818
# At batch: 111, the training accuracy is: 99.0%
# At batch: 111, the test accuracy is: 95.0%
# Current run time is: 13657.014605998993
#
# Trained 221 batches with current epoch cost: 28.773300126194954
# At batch: 221, the training accuracy is: 95.0%
# At batch: 221, the test accuracy is: 97.0%
# Current run time is: 13880.606467723846
#
# Trained 331 batches with current epoch cost: 44.21036949381232
# At batch: 331, the training accuracy is: 96.0%
# At batch: 331, the test accuracy is: 98.0%
# Current run time is: 14104.138754606247
#
# Trained 441 batches with current epoch cost: 59.492076721042395
# At batch: 441, the training accuracy is: 98.0%
# At batch: 441, the test accuracy is: 96.0%
# Current run time is: 14328.099825382233
#
# Epoch 13 completed out of: 30 loss: 73.7260972662 , time: 1118.2010011672974
#
# At end of epoch: 13, the training accuracy on batch is: 98.0%
# At end of epoch: 13, the test accuracy is: 96.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998]
# Total time taken for current epoch : 1119.581928
#
# -------Running Epoch:14-------
# Trained 1 batches with current epoch cost: 0.05583224445581436
# At batch: 1, the training accuracy is: 99.0%
# At batch: 1, the test accuracy is: 95.0%
# Current run time is: 14553.299144506454
#
# Trained 111 batches with current epoch cost: 13.236070242710412
# At batch: 111, the training accuracy is: 97.0%
# At batch: 111, the test accuracy is: 96.0%
# Current run time is: 14776.60265493393
#
# Trained 221 batches with current epoch cost: 27.158254514448345
# At batch: 221, the training accuracy is: 98.0%
# At batch: 221, the test accuracy is: 94.0%
# Current run time is: 14999.103503227234
#
# Trained 331 batches with current epoch cost: 40.092787901870906
# At batch: 331, the training accuracy is: 97.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 15221.7117228508
#
# Trained 441 batches with current epoch cost: 52.4789993125014
# At batch: 441, the training accuracy is: 98.0%
# At batch: 441, the test accuracy is: 98.0%
# Current run time is: 15444.533883571625
#
# Epoch 14 completed out of: 30 loss: 64.5356068364 , time: 1115.2046365737915
#
# At end of epoch: 14, the training accuracy on batch is: 98.0%
# At end of epoch: 14, the test accuracy is: 98.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002]
# Total time taken for current epoch : 1116.605724
#
# -------Running Epoch:15-------
# Trained 1 batches with current epoch cost: 0.031929582357406616
# At batch: 1, the training accuracy is: 98.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 15670.411537647247
#
# Trained 111 batches with current epoch cost: 11.426796171814203
# At batch: 111, the training accuracy is: 98.0%
# At batch: 111, the test accuracy is: 97.0%
# Current run time is: 15899.079853057861
#
# Trained 221 batches with current epoch cost: 25.077284436672926
# At batch: 221, the training accuracy is: 95.0%
# At batch: 221, the test accuracy is: 97.0%
# Current run time is: 16127.78107213974
#
# Trained 331 batches with current epoch cost: 36.9362623821944
# At batch: 331, the training accuracy is: 97.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 16358.036614179611
#
# Trained 441 batches with current epoch cost: 50.915172040462494
# At batch: 441, the training accuracy is: 98.0%
# At batch: 441, the test accuracy is: 95.0%
# Current run time is: 16586.632887125015
#
# Epoch 15 completed out of: 30 loss: 64.4148192825 , time: 1146.665685415268
#
# At end of epoch: 15, the training accuracy on batch is: 98.0%
# At end of epoch: 15, the test accuracy is: 96.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998]
# Total time taken for current epoch : 1148.085993
#
# -------Running Epoch:16-------
# Trained 1 batches with current epoch cost: 0.09653087705373764
# At batch: 1, the training accuracy is: 96.0%
# At batch: 1, the test accuracy is: 96.0%
# Current run time is: 16818.304344415665
#
# Trained 111 batches with current epoch cost: 10.868346141651273
# At batch: 111, the training accuracy is: 93.0%
# At batch: 111, the test accuracy is: 98.0%
# Current run time is: 17046.837901115417
#
# Trained 221 batches with current epoch cost: 22.443876586854458
# At batch: 221, the training accuracy is: 97.0%
# At batch: 221, the test accuracy is: 96.0%
# Current run time is: 17275.962474822998
#
# Trained 331 batches with current epoch cost: 34.48485754290596
# At batch: 331, the training accuracy is: 96.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 17510.27548980713
#
# Trained 441 batches with current epoch cost: 46.41645231889561
# At batch: 441, the training accuracy is: 97.0%
# At batch: 441, the test accuracy is: 97.0%
# Current run time is: 17753.745865106583
#
# Epoch 16 completed out of: 30 loss: 58.7862097728 , time: 1172.9447321891785
#
# At end of epoch: 16, the training accuracy on batch is: 97.0%
# At end of epoch: 16, the test accuracy is: 99.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001]
# Total time taken for current epoch : 1174.534828
#
# -------Running Epoch:17-------
# Trained 1 batches with current epoch cost: 0.0914480909705162
# At batch: 1, the training accuracy is: 99.0%
# At batch: 1, the test accuracy is: 99.0%
# Current run time is: 17992.79332637787
#
# Trained 111 batches with current epoch cost: 11.21832381002605
# At batch: 111, the training accuracy is: 99.0%
# At batch: 111, the test accuracy is: 98.0%
# Current run time is: 18221.428039073944
#
# Trained 221 batches with current epoch cost: 21.497213219292462
# At batch: 221, the training accuracy is: 99.0%
# At batch: 221, the test accuracy is: 100.0%
# Current run time is: 18450.452655553818
#
# Trained 331 batches with current epoch cost: 32.34392293449491
# At batch: 331, the training accuracy is: 95.0%
# At batch: 331, the test accuracy is: 96.0%
# Current run time is: 18679.23506116867
#
# Trained 441 batches with current epoch cost: 42.294245949946344
# At batch: 441, the training accuracy is: 98.0%
# At batch: 441, the test accuracy is: 96.0%
# Current run time is: 18907.532188892365
#
# Epoch 17 completed out of: 30 loss: 123.585666663 , time: 1144.5780205726624
#
# At end of epoch: 17, the training accuracy on batch is: 98.0%
# At end of epoch: 17, the test accuracy is: 80.0%
# Total time taken for current epoch : 1145.377163
#
# -------Running Epoch:18-------
# Trained 1 batches with current epoch cost: 0.5362843871116638
# At batch: 1, the training accuracy is: 83.0%
# At batch: 1, the test accuracy is: 79.0%
# Current run time is: 19137.985179185867
#
# Trained 111 batches with current epoch cost: 46.199636578559875
# At batch: 111, the training accuracy is: 93.0%
# At batch: 111, the test accuracy is: 91.0%
# Current run time is: 19366.59582543373
#
# Trained 221 batches with current epoch cost: 78.12258785963058
# At batch: 221, the training accuracy is: 96.0%
# At batch: 221, the test accuracy is: 93.0%
# Current run time is: 19595.61463689804
#
# Trained 331 batches with current epoch cost: 99.81910240650177
# At batch: 331, the training accuracy is: 94.0%
# At batch: 331, the test accuracy is: 94.0%
# Current run time is: 19825.216546058655
#
# Trained 441 batches with current epoch cost: 118.25115987844765
# At batch: 441, the training accuracy is: 100.0%
# At batch: 441, the test accuracy is: 98.0%
# Current run time is: 20053.834827423096
#
# Epoch 18 completed out of: 30 loss: 134.280008642 , time: 1144.0588841438293
#
# At end of epoch: 18, the training accuracy on batch is: 100.0%
# At end of epoch: 18, the test accuracy is: 94.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94]
# Total time taken for current epoch : 1145.530638
#
# -------Running Epoch:19-------
# Trained 1 batches with current epoch cost: 0.08857045322656631
# At batch: 1, the training accuracy is: 99.0%
# At batch: 1, the test accuracy is: 94.0%
# Current run time is: 20283.554547786713
#
# Trained 111 batches with current epoch cost: 13.913108821958303
# At batch: 111, the training accuracy is: 96.0%
# At batch: 111, the test accuracy is: 97.0%
# Current run time is: 20513.28368997574
#
# Trained 221 batches with current epoch cost: 26.652414319105446
# At batch: 221, the training accuracy is: 98.0%
# At batch: 221, the test accuracy is: 98.0%
# Current run time is: 20742.897125959396
#
# Trained 331 batches with current epoch cost: 37.9151252983138
# At batch: 331, the training accuracy is: 96.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 20972.892803430557
#
# Trained 441 batches with current epoch cost: 47.39478519605473
# At batch: 441, the training accuracy is: 97.0%
# At batch: 441, the test accuracy is: 97.0%
# Current run time is: 21201.773785829544
#
# Epoch 19 completed out of: 30 loss: 58.2531941184 , time: 1147.9945840835571
#
# At end of epoch: 19, the training accuracy on batch is: 97.0%
# At end of epoch: 19, the test accuracy is: 96.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998]
# Total time taken for current epoch : 1149.473362
#
# -------Running Epoch:20-------
# Trained 1 batches with current epoch cost: 0.09046179056167603
# At batch: 1, the training accuracy is: 98.0%
# At batch: 1, the test accuracy is: 97.0%
# Current run time is: 21433.791815519333
#
# Trained 111 batches with current epoch cost: 13.9008060824126
# At batch: 111, the training accuracy is: 97.0%
# At batch: 111, the test accuracy is: 97.0%
# Current run time is: 21664.423483371735
#
# Trained 221 batches with current epoch cost: 24.475467348471284
# At batch: 221, the training accuracy is: 99.0%
# At batch: 221, the test accuracy is: 97.0%
# Current run time is: 21893.888896226883
#
# Trained 331 batches with current epoch cost: 34.05159725761041
# At batch: 331, the training accuracy is: 99.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 22123.29172563553
#
# Trained 441 batches with current epoch cost: 43.68657967587933
# At batch: 441, the training accuracy is: 97.0%
# At batch: 441, the test accuracy is: 99.0%
# Current run time is: 22352.404512166977
#
# Epoch 20 completed out of: 30 loss: 53.3385899044 , time: 1148.4951555728912
#
# At end of epoch: 20, the training accuracy on batch is: 97.0%
# At end of epoch: 20, the test accuracy is: 97.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003]
# Total time taken for current epoch : 1149.855307
#
# -------Running Epoch:21-------
# Trained 1 batches with current epoch cost: 0.14473885297775269
# At batch: 1, the training accuracy is: 96.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 22583.158273220062
#
# Trained 111 batches with current epoch cost: 8.458056543488055
# At batch: 111, the training accuracy is: 96.0%
# At batch: 111, the test accuracy is: 96.0%
# Current run time is: 22811.621488809586
#
# Trained 221 batches with current epoch cost: 17.500174487009645
# At batch: 221, the training accuracy is: 99.0%
# At batch: 221, the test accuracy is: 97.0%
# Current run time is: 23039.937077999115
#
# Trained 331 batches with current epoch cost: 26.22182617429644
# At batch: 331, the training accuracy is: 98.0%
# At batch: 331, the test accuracy is: 96.0%
# Current run time is: 23268.995861053467
#
# Trained 441 batches with current epoch cost: 34.566751366946846
# At batch: 441, the training accuracy is: 100.0%
# At batch: 441, the test accuracy is: 97.0%
# Current run time is: 23499.34350824356
#
# Epoch 21 completed out of: 30 loss: 44.0174019416 , time: 1146.4016454219818
#
# At end of epoch: 21, the training accuracy on batch is: 100.0%
# At end of epoch: 21, the test accuracy is: 97.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003]
# Total time taken for current epoch : 1147.865022
#
# -------Running Epoch:22-------
# Trained 1 batches with current epoch cost: 0.05661725625395775
# At batch: 1, the training accuracy is: 98.0%
# At batch: 1, the test accuracy is: 97.0%
# Current run time is: 23730.77304172516
#
# Trained 111 batches with current epoch cost: 8.354569615679793
# At batch: 111, the training accuracy is: 100.0%
# At batch: 111, the test accuracy is: 97.0%
# Current run time is: 23959.50477218628
#
# Trained 221 batches with current epoch cost: 17.5915229258826
# At batch: 221, the training accuracy is: 98.0%
# At batch: 221, the test accuracy is: 97.0%
# Current run time is: 24188.634957551956
#
# Trained 331 batches with current epoch cost: 25.715685244533233
# At batch: 331, the training accuracy is: 96.0%
# At batch: 331, the test accuracy is: 100.0%
# Current run time is: 24416.902233839035
#
# Trained 441 batches with current epoch cost: 34.152148685301654
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 97.0%
# Current run time is: 24645.718024015427
#
# Epoch 22 completed out of: 30 loss: 42.9817067328 , time: 1144.2039270401
#
# At end of epoch: 22, the training accuracy on batch is: 99.0%
# At end of epoch: 22, the test accuracy is: 98.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003, 0.98000002]
# Total time taken for current epoch : 1145.624406
#
# -------Running Epoch:23-------
# Trained 1 batches with current epoch cost: 0.03936675190925598
# At batch: 1, the training accuracy is: 98.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 24876.514683246613
#
# Trained 111 batches with current epoch cost: 7.8246828133706
# At batch: 111, the training accuracy is: 98.0%
# At batch: 111, the test accuracy is: 99.0%
# Current run time is: 25103.36189198494
#
# Trained 221 batches with current epoch cost: 16.304871916072443
# At batch: 221, the training accuracy is: 99.0%
# At batch: 221, the test accuracy is: 98.0%
# Current run time is: 25331.25384569168
#
# Trained 331 batches with current epoch cost: 24.831241827690974
# At batch: 331, the training accuracy is: 97.0%
# At batch: 331, the test accuracy is: 95.0%
# Current run time is: 25559.560057401657
#
# Trained 441 batches with current epoch cost: 34.5182952710893
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 100.0%
# Current run time is: 25787.91467356682
#
# Epoch 23 completed out of: 30 loss: 42.2499387937 , time: 1140.9386639595032
#
# At end of epoch: 23, the training accuracy on batch is: 99.0%
# At end of epoch: 23, the test accuracy is: 98.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003, 0.98000002, 0.98000002]
# Total time taken for current epoch : 1142.419355
#
# -------Running Epoch:24-------
# Trained 1 batches with current epoch cost: 0.022807588800787926
# At batch: 1, the training accuracy is: 100.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 26018.7950527668
#
# Trained 111 batches with current epoch cost: 7.815603177063167
# At batch: 111, the training accuracy is: 99.0%
# At batch: 111, the test accuracy is: 99.0%
# Current run time is: 26247.13730573654
#
# Trained 221 batches with current epoch cost: 16.93093920685351
# At batch: 221, the training accuracy is: 100.0%
# At batch: 221, the test accuracy is: 99.0%
# Current run time is: 26475.31507563591
#
# Trained 331 batches with current epoch cost: 24.325973275583237
# At batch: 331, the training accuracy is: 98.0%
# At batch: 331, the test accuracy is: 98.0%
# Current run time is: 26703.412855625153
#
# Trained 441 batches with current epoch cost: 31.11405824869871
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 99.0%
# Current run time is: 26931.06813311577
#
# Epoch 24 completed out of: 30 loss: 38.3905516276 , time: 1142.6223328113556
#
# At end of epoch: 24, the training accuracy on batch is: 99.0%
# At end of epoch: 24, the test accuracy is: 97.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003, 0.98000002, 0.98000002, 0.97000003]
# Total time taken for current epoch : 1143.989515
#
# -------Running Epoch:25-------
# Trained 1 batches with current epoch cost: 0.13675498962402344
# At batch: 1, the training accuracy is: 95.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 27163.078719615936
#
# Trained 111 batches with current epoch cost: 7.389320256188512
# At batch: 111, the training accuracy is: 98.0%
# At batch: 111, the test accuracy is: 98.0%
# Current run time is: 27391.085889339447
#
# Trained 221 batches with current epoch cost: 14.288558383006603
# At batch: 221, the training accuracy is: 97.0%
# At batch: 221, the test accuracy is: 99.0%
# Current run time is: 27619.534368276596
#
# Trained 331 batches with current epoch cost: 23.759237070102245
# At batch: 331, the training accuracy is: 100.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 27848.244871616364
#
# Trained 441 batches with current epoch cost: 31.6586866597645
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 96.0%
# Current run time is: 28076.583197832108
#
# Epoch 25 completed out of: 30 loss: 38.7959964368 , time: 1143.1268093585968
#
# At end of epoch: 25, the training accuracy on batch is: 99.0%
# At end of epoch: 25, the test accuracy is: 98.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003, 0.98000002, 0.98000002, 0.97000003, 0.98000002]
# Total time taken for current epoch : 1144.490834
#
# -------Running Epoch:26-------
# Trained 1 batches with current epoch cost: 0.11519219726324081
# At batch: 1, the training accuracy is: 98.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 28307.59834933281
#
# Trained 111 batches with current epoch cost: 8.24121115077287
# At batch: 111, the training accuracy is: 99.0%
# At batch: 111, the test accuracy is: 98.0%
# Current run time is: 28536.152913808823
#
# Trained 221 batches with current epoch cost: 15.417078105034307
# At batch: 221, the training accuracy is: 99.0%
# At batch: 221, the test accuracy is: 99.0%
# Current run time is: 28766.31385064125
#
# Trained 331 batches with current epoch cost: 22.871694827685133
# At batch: 331, the training accuracy is: 99.0%
# At batch: 331, the test accuracy is: 100.0%
# Current run time is: 28994.542944192886
#
# Trained 441 batches with current epoch cost: 30.000387005275115
# At batch: 441, the training accuracy is: 96.0%
# At batch: 441, the test accuracy is: 99.0%
# Current run time is: 29223.915679216385
#
# Epoch 26 completed out of: 30 loss: 37.2496742299 , time: 1146.3936960697174
#
# At end of epoch: 26, the training accuracy on batch is: 96.0%
# At end of epoch: 26, the test accuracy is: 99.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003, 0.98000002, 0.98000002, 0.97000003, 0.98000002, 0.99000001]
# Total time taken for current epoch : 1147.812065
#
# -------Running Epoch:27-------
# Trained 1 batches with current epoch cost: 0.08152610808610916
# At batch: 1, the training accuracy is: 98.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 29455.055035591125
#
# Trained 111 batches with current epoch cost: 5.969733269885182
# At batch: 111, the training accuracy is: 99.0%
# At batch: 111, the test accuracy is: 98.0%
# Current run time is: 29682.873585939407
#
# Trained 221 batches with current epoch cost: 14.006318755447865
# At batch: 221, the training accuracy is: 100.0%
# At batch: 221, the test accuracy is: 96.0%
# Current run time is: 29910.76441192627
#
# Trained 331 batches with current epoch cost: 20.748330439208075
# At batch: 331, the training accuracy is: 99.0%
# At batch: 331, the test accuracy is: 98.0%
# Current run time is: 30138.627266407013
#
# Trained 441 batches with current epoch cost: 27.323010542197153
# At batch: 441, the training accuracy is: 100.0%
# At batch: 441, the test accuracy is: 99.0%
# Current run time is: 30366.26766371727
#
# Epoch 27 completed out of: 30 loss: 34.0999198314 , time: 1141.0814838409424
#
# At end of epoch: 27, the training accuracy on batch is: 100.0%
# At end of epoch: 27, the test accuracy is: 98.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003, 0.98000002, 0.98000002, 0.97000003, 0.98000002, 0.99000001, 0.98000002]
# Total time taken for current epoch : 1142.449581
#
# -------Running Epoch:28-------
# Trained 1 batches with current epoch cost: 0.0730229914188385
# At batch: 1, the training accuracy is: 98.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 30597.847389936447
#
# Trained 111 batches with current epoch cost: 5.858943327097222
# At batch: 111, the training accuracy is: 99.0%
# At batch: 111, the test accuracy is: 98.0%
# Current run time is: 30824.68426012993
#
# Trained 221 batches with current epoch cost: 12.5797384143807
# At batch: 221, the training accuracy is: 97.0%
# At batch: 221, the test accuracy is: 96.0%
# Current run time is: 31051.828956127167
#
# Trained 331 batches with current epoch cost: 19.25079670129344
# At batch: 331, the training accuracy is: 99.0%
# At batch: 331, the test accuracy is: 98.0%
# Current run time is: 31280.054713010788
#
# Trained 441 batches with current epoch cost: 26.119767896831036
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 98.0%
# Current run time is: 31506.940095424652
#
# Epoch 28 completed out of: 30 loss: 34.502969184 , time: 1137.2309727668762
#
# At end of epoch: 28, the training accuracy on batch is: 99.0%
# At end of epoch: 28, the test accuracy is: 99.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003, 0.98000002, 0.98000002, 0.97000003, 0.98000002, 0.99000001, 0.98000002, 0.99000001]
# Total time taken for current epoch : 1138.579324
#
# -------Running Epoch:29-------
# Trained 1 batches with current epoch cost: 0.02300359308719635
# At batch: 1, the training accuracy is: 100.0%
# At batch: 1, the test accuracy is: 100.0%
# Current run time is: 31736.101268291473
#
# Trained 111 batches with current epoch cost: 34.227919147815555
# At batch: 111, the training accuracy is: 89.0%
# At batch: 111, the test accuracy is: 92.0%
# Current run time is: 31964.95271921158
#
# Trained 221 batches with current epoch cost: 51.295943622943014
# At batch: 221, the training accuracy is: 96.0%
# At batch: 221, the test accuracy is: 96.0%
# Current run time is: 32193.10106229782
#
# Trained 331 batches with current epoch cost: 63.604698167648166
# At batch: 331, the training accuracy is: 98.0%
# At batch: 331, the test accuracy is: 98.0%
# Current run time is: 32421.056979179382
#
# Trained 441 batches with current epoch cost: 74.97197349509224
# At batch: 441, the training accuracy is: 97.0%
# At batch: 441, the test accuracy is: 99.0%
# Current run time is: 32647.36659526825
#
# Epoch 29 completed out of: 30 loss: 85.048439519 , time: 1138.8782413005829
#
# At end of epoch: 29, the training accuracy on batch is: 97.0%
# At end of epoch: 29, the test accuracy is: 98.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003, 0.98000002, 0.98000002, 0.97000003, 0.98000002, 0.99000001, 0.98000002, 0.99000001, 0.98000002]
# Total time taken for current epoch : 1140.268521
#
# -------Running Epoch:30-------
# Trained 1 batches with current epoch cost: 0.22894781827926636
# At batch: 1, the training accuracy is: 96.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 32876.380491256714
#
# Trained 111 batches with current epoch cost: 13.18459302932024
# At batch: 111, the training accuracy is: 96.0%
# At batch: 111, the test accuracy is: 96.0%
# Current run time is: 33103.3777487278
#
# Trained 221 batches with current epoch cost: 21.598789727315307
# At batch: 221, the training accuracy is: 95.0%
# At batch: 221, the test accuracy is: 98.0%
# Current run time is: 33330.92595052719
#
# Trained 331 batches with current epoch cost: 28.974048199132085
# At batch: 331, the training accuracy is: 98.0%
# At batch: 331, the test accuracy is: 98.0%
# Current run time is: 33558.13575339317
#
# Trained 441 batches with current epoch cost: 35.862972300034016
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 97.0%
# Current run time is: 33785.455176353455
#
# Epoch 30 completed out of: 30 loss: 42.5687251058 , time: 1137.3390038013458
#
# At end of epoch: 30, the training accuracy on batch is: 99.0%
# At end of epoch: 30, the test accuracy is: 97.0%
# [0.51999998, 0.61000001, 0.67000002, 0.77999997, 0.80000001, 0.86000001, 0.89999998, 0.94999999, 0.92000002, 0.92000002, 0.95999998, 0.94999999, 0.95999998, 0.98000002, 0.95999998, 0.99000001, 0.80000001, 0.94, 0.95999998, 0.97000003, 0.97000003, 0.98000002, 0.98000002, 0.97000003, 0.98000002, 0.99000001, 0.98000002, 0.99000001, 0.98000002, 0.97000003]
# Total time taken for current epoch : 1138.690683
#
# At final epoch: 30, the test accuracy is: 98.0%, with cost 0.06556057929992676
# Total time taken for run : 34132.680451

# %% [markdown]
# # Restoring model
# Here the model is restored and the values in the report match the recovered ones.

# %%
def print_acc(rnn_size,epochs):
    
    acc_test_list = []
    acc_train_list = []
    cost_train_list = []
    cost_test_list =[]
    b_size = 1000
    num_train = len(mnist.train.labels)
    num_test = len(mnist.test.labels)
    
    # Comment out here to use whole training set!
    num_train = len(mnist.train.labels[:10000,:])
    n_batches = num_train/b_size
    count = 0
    i = 0
    start = time.time()
    while i < num_train:
        print('Processing batch number {} of {}.'.format(count+1,n_batches))
        # The ending index for the next batch is denoted j.
        j = min(i + b_size, num_train)
        
        if j<= num_test:
            
            # Get the images from the test-set between index i and j.
            images_test = mnist.test.images.reshape((-1, 784, 1))[i:j, :]

            # Get the associated labels.
            labels_test = mnist.test.labels[i:j, :]

            acc_test, cost_test = sess.run([accuracy,cost],feed_dict = {x: binarize(images_test), y: labels_test})
            #print(cost_test)

            acc_test_list.append(acc_test)
            cost_test_list.append(cost_test)
        images_train = mnist.train.images.reshape((-1, 784, 1))[i:j, :]

        # Get the associated labels.
        labels_test = mnist.train.labels[i:j, :]

        acc_train,cost_train = sess.run([accuracy,cost],feed_dict = {x: binarize(images_train), y: labels_test})
        acc_train_list.append(acc_train)
        cost_train_list.append(cost_train)
        i = j
        count +=1
        
    #print(cost)
    #print(time.time()-start)
    print('\n')
    
    total_acc_train = sum(acc_train_list)/len(acc_train_list)
    total_acc_test = sum(acc_test_list)/len(acc_test_list)
    total_cost_train = sum(cost_train_list)/len(cost_train_list)
    total_cost_test = sum(cost_test_list)/len(cost_test_list)
    #print(total_acc)
    #total_cost = sum(cost)/len(cost)
    print(time.time()-start)
    print('The training accuracy for the 3 layer {} unit GRU model is {:.1%} after {} epochs'.format(rnn_size,total_acc_train,epochs))
    print('The training cost for the 3 layer {} unit GRU model is {} after {} epochs \n'.format(rnn_size,total_cost_train,epochs))
    print('The test accuracy for the 3 layer {} unit GRU model is {:.1%} after {} epochs'.format(rnn_size,total_acc_test,epochs))
    print('The test cost for the 3 layer {} unit GRU model is {} after {} epochs \n'.format(rnn_size,total_cost_test,epochs))
    return(total_acc_train,total_acc_test)

# %%
save_MDir = 'models/gru128/'
save_model = os.path.join(save_MDir,'best_accuracy_3')
init = tf.global_variables_initializer()

# %%
sess= tf.Session()
sess.run(init)
saver2restore = tf.train.Saver()
saver2restore.restore(sess = sess, save_path= save_model)

# %%
print_acc(rnn_size=128, epochs = 30)
sess.close()
# Out:
# Processing batch number 1 of 55.0.
# Processing batch number 2 of 55.0.
# Processing batch number 3 of 55.0.
# Processing batch number 4 of 55.0.
# Processing batch number 5 of 55.0.
# Processing batch number 6 of 55.0.
# Processing batch number 7 of 55.0.
# Processing batch number 8 of 55.0.
# Processing batch number 9 of 55.0.
# Processing batch number 10 of 55.0.
# Processing batch number 11 of 55.0.
# Processing batch number 12 of 55.0.
# Processing batch number 13 of 55.0.
# Processing batch number 14 of 55.0.
# Processing batch number 15 of 55.0.
# Processing batch number 16 of 55.0.
# Processing batch number 17 of 55.0.
# Processing batch number 18 of 55.0.
# Processing batch number 19 of 55.0.
# Processing batch number 20 of 55.0.
# Processing batch number 21 of 55.0.
# Processing batch number 22 of 55.0.
# Processing batch number 23 of 55.0.
# Processing batch number 24 of 55.0.
# Processing batch number 25 of 55.0.
# Processing batch number 26 of 55.0.
# Processing batch number 27 of 55.0.
# Processing batch number 28 of 55.0.
# Processing batch number 29 of 55.0.
# Processing batch number 30 of 55.0.
# Processing batch number 31 of 55.0.
# Processing batch number 32 of 55.0.
# Processing batch number 33 of 55.0.
# Processing batch number 34 of 55.0.
# Processing batch number 35 of 55.0.
# Processing batch number 36 of 55.0.
# Processing batch number 37 of 55.0.
# Processing batch number 38 of 55.0.
# Processing batch number 39 of 55.0.
# Processing batch number 40 of 55.0.
# Processing batch number 41 of 55.0.
# Processing batch number 42 of 55.0.
# Processing batch number 43 of 55.0.
# Processing batch number 44 of 55.0.
# Processing batch number 45 of 55.0.
# Processing batch number 46 of 55.0.
# Processing batch number 47 of 55.0.
# Processing batch number 48 of 55.0.
# Processing batch number 49 of 55.0.
# Processing batch number 50 of 55.0.
# Processing batch number 51 of 55.0.
# Processing batch number 52 of 55.0.
# Processing batch number 53 of 55.0.
# Processing batch number 54 of 55.0.
# Processing batch number 55 of 55.0.
#
#
# 342.1091754436493
# The training accuracy for the 3 layer 128 unit GRU model is 98.3% after 30 epochs
# The training cost for the 3 layer 128 unit GRU model is 0.05642490915276788 after 30 epochs
#
# The test accuracy for the 3 layer 128 unit GRU model is 98.0% after 30 epochs
# The test cost for the 3 layer 128 unit GRU model is 0.06556065753102303 after 30 epochs

# %%
print_acc(rnn_size=128, epochs = 30)
sess.close()
# Out:
# Processing batch number 1 of 10.0.
# Processing batch number 2 of 10.0.
# Processing batch number 3 of 10.0.
# Processing batch number 4 of 10.0.
# Processing batch number 5 of 10.0.
# Processing batch number 6 of 10.0.
# Processing batch number 7 of 10.0.
# Processing batch number 8 of 10.0.
# Processing batch number 9 of 10.0.
# Processing batch number 10 of 10.0.
#
#
# 107.5932993888855
# The training accuracy for the 3 layer 128 unit GRU model is 98.5% after 30 epochs
# The training cost for the 3 layer 128 unit GRU model is 0.05478904116898775 after 30 epochs
#
# The test accuracy for the 3 layer 128 unit GRU model is 98.0% after 30 epochs
# The test cost for the 3 layer 128 unit GRU model is 0.06556065753102303 after 30 epochs
