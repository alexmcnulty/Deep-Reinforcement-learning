# %% [markdown]
# # Task1: Many to one Model:GRU 3 Layer
# In this task we classifiy the MNSIT data set by using a RNN of different sizes and differnt cells. The binarized images are passed into the RNN cell one pixel at a time and the final output is taken. Here the output is transformed into fully connected layer of 100 units with a ReLU activation function. It
# is then passed through another linear layer of width 10 and a softmax operation is used to get the probabilites of each digit. Cross entropy loss function is used for the cost and the Adam optimizer is used to minimize this value.
#
# It was noted that the lstm cell was quite unstable and did not perform as well as the GRU cell over the same number of epochs. Many different learning rates turned out to be too small to learn anything in time or to large such that it would quite well for some time till it jumped to much and lost all accuracy.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math

import os
import pdb

# %%
# Need to load the MNist data to work with
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/MNIST/", one_hot=True)
# one hot true gives the y labels as vectors with 1's which correspond to the number it is
# Out:
# Extracting data/MNIST/train-images-idx3-ubyte.gz
# Extracting data/MNIST/train-labels-idx1-ubyte.gz
# Extracting data/MNIST/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST/t10k-labels-idx1-ubyte.gz

# %%
print('The size of the data that we will be working with:')
print('train set: {} '.format(len(mnist.train.labels)))
print('valid set: {} '.format(len(mnist.validation.labels)))
print('test set: {} '.format(len(mnist.test.labels)))
# Out:
# The size of the data that we will be working with:
# train set: 55000
# valid set: 5000
# test set: 10000

# %%
# define parameters
n_classes = 10 # digits
batch_size = 100
chunk_size = 1 # input per timestep
n_chunks = 784 # number of pixels/timesteps
rnn_size = 32
units_output = 100 # output after rnn
learning_rate = 0.001

# placeholders tp store the inputs and labels 
x = tf.placeholder('float', [None, n_chunks,chunk_size],name='InputData')
y = tf.placeholder('float',name='LabelData')

logs_path = '/tmp/tensorflow_logs/example'

# %%
layer1 = {'weights':tf.Variable(tf.random_normal([rnn_size,units_output]),name='Weights1'),
             'biases':tf.Variable(tf.random_normal([units_output]),name='Bias')}
layer2 = {'weights':tf.Variable(tf.random_normal([units_output,n_classes]),name='Weights2'),
             'biases':tf.Variable(tf.random_normal([n_classes]),name='Bias2')}

# %%
# Here the gru cell is defined of specified size
gru_cell = tf.nn.rnn_cell.GRUCell(rnn_size)

# make it 3 layers
gru_cell = tf.nn.rnn_cell.MultiRNNCell(cells=[gru_cell] * 3, state_is_tuple=True)

# The ouputs are a tensor of all the ouput states of the pixels
# interested only in the last
outputs, states = tf.nn.dynamic_rnn(cell = gru_cell, inputs = x,dtype=tf.float32)

# Checking to make sure of the correct shape
print(outputs.get_shape())
# Out:
# (?, 784, 32)

# %%
# Many to one model so we need only the last output of the rnn.
outputs = outputs[:, -1, :]

# linear transformation
output_rnn = tf.matmul(outputs,layer1['weights']) + layer1['biases']

# Relu activation
act = tf.nn.relu(output_rnn)

# linear transformatino
output = tf.matmul(act,layer2['weights'])+layer2['biases']

# calculate cost of batch
Xent =  tf.nn.softmax_cross_entropy_with_logits(output,y)

# calculate the average cost per image and optimize
with tf.name_scope('Loss'):
    cost = tf.reduce_mean( Xent )
with tf.name_scope('Adam'):    
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# Calculate the accuracy by comparing the output label with the true label of the images

# %%
# create a boolean of correct labels and take the average to 
# get the percentage of correctly available
with tf.name_scope('Accuracy'):
    correct_label = tf.equal(tf.argmax(output, 1), tf.argmax(y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_label, tf.float32))

# %% [markdown]
# ### Save the models

# %%
# Need to save the model, weights and biases varibles
saver = tf.train.Saver(write_version = tf.train.SaverDef.V2)

# Suggested Directory to use
save_MDir = 'models/3Layer_gru/'


#create the directory if it does not exist already
if not os.path.exists(save_MDir):
    os.makedirs(save_MDir)

save_model = os.path.join(save_MDir,'best_accuracy_3')

# %%
# Need to save the model, weights and biases varibles
saver2 = tf.train.Saver()

# Suggested Directory to use
save2_MDir = 'models/3Layer_gru/best'


#create the directory if it does not exist already
if not os.path.exists(save2_MDir):
    os.makedirs(save2_MDir)

save_model2 = os.path.join(save2_MDir,'best_accuracy_3')

# %% [markdown]
# ### Save the models

# %%
def binarize(images, threshold=0.1):
    return (threshold < images).astype("float32")

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# Create a summary to monitor cost tensor
tf.summary.scalar("loss", cost)
# Create a summary to monitor accuracy tensor
tf.summary.scalar("accuracy", accuracy)
# Merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()

# %% [markdown]
# ### Optimizer function
# Here the main work is done. Each batch is passed through and outputs the cost at the end of each epoch.

# %%
def optimize(hm_epochs):
    with tf.Session() as sess:
        sess.run(init)
        summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())        
        start_epoch = time.time()
        freq_epoch = 1
        count = 0
        acc_list = []
        for epoch in range(hm_epochs):
            print("-------Running Epoch:{}-------".format(epoch+1))
            epoch_loss = 0
            
            start = time.time()
            n_batches = int(mnist.train.num_examples/batch_size)
            #n_batches = 10
            freq = int(n_batches/5)
            for i in range(n_batches):
                epoch_x, epoch_y = mnist.train.next_batch(batch_size)
                epoch_x = binarize(epoch_x)
                epoch_x = epoch_x.reshape((batch_size,n_chunks,chunk_size))


                _, c,summary = sess.run([optimizer, cost,merged_summary_op], feed_dict={x: epoch_x, y: epoch_y})
                summary_writer.add_summary(summary, epoch * n_batches + i)
                epoch_loss += c
                if i% freq ==0 or i == (n_batches):
                    print("Trained {} batches with current epoch cost: {}".format(i+1,epoch_loss))
                    acc_train = sess.run(accuracy,feed_dict = {x: epoch_x, y: epoch_y})
                    acc_test = accuracy.eval({x: binarize(mnist.test.images[0:batch_size].reshape((-1, 784, 1))), y: mnist.test.labels[0:batch_size]})
                    print("At batch: {0}, the training accuracy is: {1:.1%}".format(i+1, acc_train))
                    print("At batch: {0}, the test accuracy is: {1:.1%}".format(i+1, acc_test))
                    print("Current run time is: {} \n".format(time.time()-start_epoch))
                    
            if epoch % freq_epoch==0:
                print('Epoch', epoch+1, 'completed out of:',hm_epochs,'loss:',epoch_loss, ', time:', time.time()-start,'\n')            
                acc = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(output, 1), tf.argmax(y, 1)), 'float'))
                acc_test = acc.eval({x: binarize(mnist.test.images.reshape((-1, 784, 1))), y: mnist.test.labels})
                acc_list.append(acc_test)
                print("At end of epoch: {0}, the training accuracy in batch is: {1:.1%}".format(epoch+1, acc_train))
                print("At end of epoch: {}, the test accuracy is: {:.1%}".format(epoch+1, acc_test))
                if epoch>=0:
                    if acc_list[count]== max(acc_list):
                        saver2.save(sess= sess, save_path = save_model2)
                        print(acc_list)
                        
                        
                count = count+1

                print("Total time taken for current epoch : {:f} \n".format(time.time()-start))
        
        
        Final_acc_test,Final_cost_test = sess.run([accuracy,cost],feed_dict = {x: binarize(mnist.test.images.reshape((-1, 784, 1))), y: mnist.test.labels})
        saver.save(sess= sess, save_path = save_model)        
        print("At final epoch: {}, the test accuracy is: {:.1%}, with cost {}".format(epoch+1, Final_acc_test, Final_cost_test))
    print("Total time taken for run : {:f}".format(time.time()-start_epoch))

# %%
#optimize(30)
# Out:
# -------Running Epoch:1-------
# Trained 1 batches with current epoch cost: 7.126248836517334
# At batch: 1, the training accuracy is: 12.0%
# At batch: 1, the test accuracy is: 8.0%
# Current run time is: 3.17871356010437
#
# Trained 111 batches with current epoch cost: 274.37916803359985
# At batch: 111, the training accuracy is: 30.0%
# At batch: 111, the test accuracy is: 38.0%
# Current run time is: 274.9030005931854
#
# Trained 221 batches with current epoch cost: 473.86110866069794
# At batch: 221, the training accuracy is: 37.0%
# At batch: 221, the test accuracy is: 40.0%
# Current run time is: 510.1500380039215
#
# Trained 331 batches with current epoch cost: 673.8907819986343
# At batch: 331, the training accuracy is: 34.0%
# At batch: 331, the test accuracy is: 30.0%
# Current run time is: 730.2748701572418
#
# Trained 441 batches with current epoch cost: 870.9061751365662
# At batch: 441, the training accuracy is: 31.0%
# At batch: 441, the test accuracy is: 34.0%
# Current run time is: 893.6729032993317
#
# Epoch 1 completed out of: 30 loss: 1062.91240382 , time: 1038.7717926502228
#
# At end of epoch: 1, the training accuracy in batch is: 31.0%
# At end of epoch: 1, the test accuracy is: 31.7%
# [0.31729999]
# Total time taken for current epoch : 1076.793397
#
# -------Running Epoch:2-------
# Trained 1 batches with current epoch cost: 1.8086735010147095
# At batch: 1, the training accuracy is: 33.0%
# At batch: 1, the test accuracy is: 39.0%
# Current run time is: 1078.369313955307
#
# Trained 111 batches with current epoch cost: 193.2526023387909
# At batch: 111, the training accuracy is: 40.0%
# At batch: 111, the test accuracy is: 39.0%
# Current run time is: 1183.8415098190308
#
# Trained 221 batches with current epoch cost: 381.41617357730865
# At batch: 221, the training accuracy is: 32.0%
# At batch: 221, the test accuracy is: 45.0%
# Current run time is: 1278.65558218956
#
# Trained 331 batches with current epoch cost: 554.064201593399
# At batch: 331, the training accuracy is: 42.0%
# At batch: 331, the test accuracy is: 45.0%
# Current run time is: 1376.4951367378235
#
# Trained 441 batches with current epoch cost: 712.2801632881165
# At batch: 441, the training accuracy is: 47.0%
# At batch: 441, the test accuracy is: 50.0%
# Current run time is: 1505.7768869400024
#
# Epoch 2 completed out of: 30 loss: 862.012741446 , time: 553.0225112438202
#
# At end of epoch: 2, the training accuracy in batch is: 47.0%
# At end of epoch: 2, the test accuracy is: 47.7%
# [0.31729999, 0.4772]
# Total time taken for current epoch : 589.313702
#
# -------Running Epoch:3-------
# Trained 1 batches with current epoch cost: 1.3474349975585938
# At batch: 1, the training accuracy is: 45.0%
# At batch: 1, the test accuracy is: 48.0%
# Current run time is: 1667.5673241615295
#
# Trained 111 batches with current epoch cost: 147.3079160451889
# At batch: 111, the training accuracy is: 45.0%
# At batch: 111, the test accuracy is: 51.0%
# Current run time is: 1763.8925852775574
#
# Trained 221 batches with current epoch cost: 290.98648023605347
# At batch: 221, the training accuracy is: 54.0%
# At batch: 221, the test accuracy is: 54.0%
# Current run time is: 1853.7991261482239
#
# Trained 331 batches with current epoch cost: 433.53116106987
# At batch: 331, the training accuracy is: 48.0%
# At batch: 331, the test accuracy is: 52.0%
# Current run time is: 1947.4928362369537
#
# Trained 441 batches with current epoch cost: 569.0213924050331
# At batch: 441, the training accuracy is: 63.0%
# At batch: 441, the test accuracy is: 63.0%
# Current run time is: 2037.8517982959747
#
# Epoch 3 completed out of: 30 loss: 693.098964095 , time: 460.94643545150757
#
# At end of epoch: 3, the training accuracy in batch is: 63.0%
# At end of epoch: 3, the test accuracy is: 59.9%
# [0.31729999, 0.4772, 0.59939998]
# Total time taken for current epoch : 497.738910
#
# -------Running Epoch:4-------
# Trained 1 batches with current epoch cost: 1.1166598796844482
# At batch: 1, the training accuracy is: 64.0%
# At batch: 1, the test accuracy is: 61.0%
# Current run time is: 2165.2872297763824
#
# Trained 111 batches with current epoch cost: 119.77451902627945
# At batch: 111, the training accuracy is: 66.0%
# At batch: 111, the test accuracy is: 62.0%
# Current run time is: 2257.1094541549683
#
# Trained 221 batches with current epoch cost: 231.12623745203018
# At batch: 221, the training accuracy is: 65.0%
# At batch: 221, the test accuracy is: 65.0%
# Current run time is: 2349.0474371910095
#
# Trained 331 batches with current epoch cost: 337.60938173532486
# At batch: 331, the training accuracy is: 66.0%
# At batch: 331, the test accuracy is: 68.0%
# Current run time is: 2443.2095263004303
#
# Trained 441 batches with current epoch cost: 445.93243193626404
# At batch: 441, the training accuracy is: 63.0%
# At batch: 441, the test accuracy is: 71.0%
# Current run time is: 2544.341953754425
#
# Epoch 4 completed out of: 30 loss: 548.862169921 , time: 474.2299575805664
#
# At end of epoch: 4, the training accuracy in batch is: 63.0%
# At end of epoch: 4, the test accuracy is: 68.0%
# [0.31729999, 0.4772, 0.59939998, 0.68010002]
# Total time taken for current epoch : 511.171011
#
# -------Running Epoch:5-------
# Trained 1 batches with current epoch cost: 1.0094401836395264
# At batch: 1, the training accuracy is: 66.0%
# At batch: 1, the test accuracy is: 69.0%
# Current run time is: 2676.4673461914062
#
# Trained 111 batches with current epoch cost: 104.65569746494293
# At batch: 111, the training accuracy is: 69.0%
# At batch: 111, the test accuracy is: 63.0%
# Current run time is: 2769.0003232955933
#
# Trained 221 batches with current epoch cost: 205.58307528495789
# At batch: 221, the training accuracy is: 62.0%
# At batch: 221, the test accuracy is: 73.0%
# Current run time is: 2863.363472223282
#
# Trained 331 batches with current epoch cost: 303.0266074538231
# At batch: 331, the training accuracy is: 66.0%
# At batch: 331, the test accuracy is: 72.0%
# Current run time is: 2956.144900560379
#
# Trained 441 batches with current epoch cost: 397.1669266819954
# At batch: 441, the training accuracy is: 68.0%
# At batch: 441, the test accuracy is: 69.0%
# Current run time is: 3047.712422132492
#
# Epoch 5 completed out of: 30 loss: 485.683625698 , time: 471.1860284805298
#
# At end of epoch: 5, the training accuracy in batch is: 68.0%
# At end of epoch: 5, the test accuracy is: 72.0%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003]
# Total time taken for current epoch : 511.493448
#
# -------Running Epoch:6-------
# Trained 1 batches with current epoch cost: 0.8005445599555969
# At batch: 1, the training accuracy is: 68.0%
# At batch: 1, the test accuracy is: 72.0%
# Current run time is: 3188.50563287735
#
# Trained 111 batches with current epoch cost: 87.09696590900421
# At batch: 111, the training accuracy is: 68.0%
# At batch: 111, the test accuracy is: 76.0%
# Current run time is: 3303.0866022109985
#
# Trained 221 batches with current epoch cost: 165.2153593301773
# At batch: 221, the training accuracy is: 72.0%
# At batch: 221, the test accuracy is: 73.0%
# Current run time is: 3402.84729552269
#
# Trained 331 batches with current epoch cost: 242.5652514398098
# At batch: 331, the training accuracy is: 76.0%
# At batch: 331, the test accuracy is: 76.0%
# Current run time is: 3501.422474861145
#
# Trained 441 batches with current epoch cost: 315.6078841686249
# At batch: 441, the training accuracy is: 83.0%
# At batch: 441, the test accuracy is: 77.0%
# Current run time is: 3607.882846593857
#
# Epoch 6 completed out of: 30 loss: 385.113576829 , time: 527.4477045536041
#
# At end of epoch: 6, the training accuracy in batch is: 83.0%
# At end of epoch: 6, the test accuracy is: 78.2%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816]
# Total time taken for current epoch : 567.419651
#
# -------Running Epoch:7-------
# Trained 1 batches with current epoch cost: 0.5527756214141846
# At batch: 1, the training accuracy is: 81.0%
# At batch: 1, the test accuracy is: 73.0%
# Current run time is: 3755.5836255550385
#
# Trained 111 batches with current epoch cost: 69.20812100172043
# At batch: 111, the training accuracy is: 80.0%
# At batch: 111, the test accuracy is: 78.0%
# Current run time is: 3854.7875678539276
#
# Trained 221 batches with current epoch cost: 136.6452887058258
# At batch: 221, the training accuracy is: 83.0%
# At batch: 221, the test accuracy is: 80.0%
# Current run time is: 3958.198799133301
#
# Trained 331 batches with current epoch cost: 202.29150339961052
# At batch: 331, the training accuracy is: 80.0%
# At batch: 331, the test accuracy is: 76.0%
# Current run time is: 4061.2607610225677
#
# Trained 441 batches with current epoch cost: 265.6693313419819
# At batch: 441, the training accuracy is: 83.0%
# At batch: 441, the test accuracy is: 76.0%
# Current run time is: 4174.435969114304
#
# Epoch 7 completed out of: 30 loss: 329.841554344 , time: 524.1312544345856
#
# At end of epoch: 7, the training accuracy in batch is: 83.0%
# At end of epoch: 7, the test accuracy is: 79.1%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998]
# Total time taken for current epoch : 562.569394
#
# -------Running Epoch:8-------
# Trained 1 batches with current epoch cost: 0.5802745819091797
# At batch: 1, the training accuracy is: 82.0%
# At batch: 1, the test accuracy is: 78.0%
# Current run time is: 4318.054726839066
#
# Trained 111 batches with current epoch cost: 63.809965401887894
# At batch: 111, the training accuracy is: 82.0%
# At batch: 111, the test accuracy is: 81.0%
# Current run time is: 4418.150315999985
#
# Trained 221 batches with current epoch cost: 123.46039259433746
# At batch: 221, the training accuracy is: 79.0%
# At batch: 221, the test accuracy is: 78.0%
# Current run time is: 4527.325776338577
#
# Trained 331 batches with current epoch cost: 185.07745495438576
# At batch: 331, the training accuracy is: 81.0%
# At batch: 331, the test accuracy is: 77.0%
# Current run time is: 4630.020309209824
#
# Trained 441 batches with current epoch cost: 244.21556368470192
# At batch: 441, the training accuracy is: 75.0%
# At batch: 441, the test accuracy is: 80.0%
# Current run time is: 4737.141069173813
#
# Epoch 8 completed out of: 30 loss: 302.431392372 , time: 525.5956857204437
#
# At end of epoch: 8, the training accuracy in batch is: 75.0%
# At end of epoch: 8, the test accuracy is: 80.9%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997]
# Total time taken for current epoch : 565.489589
#
# -------Running Epoch:9-------
# Trained 1 batches with current epoch cost: 0.5176584124565125
# At batch: 1, the training accuracy is: 84.0%
# At batch: 1, the test accuracy is: 79.0%
# Current run time is: 4883.626955986023
#
# Trained 111 batches with current epoch cost: 57.70639210939407
# At batch: 111, the training accuracy is: 82.0%
# At batch: 111, the test accuracy is: 83.0%
# Current run time is: 4995.697636604309
#
# Trained 221 batches with current epoch cost: 114.35520792007446
# At batch: 221, the training accuracy is: 82.0%
# At batch: 221, the test accuracy is: 81.0%
# Current run time is: 5107.428691864014
#
# Trained 331 batches with current epoch cost: 171.95205810666084
# At batch: 331, the training accuracy is: 80.0%
# At batch: 331, the test accuracy is: 80.0%
# Current run time is: 5218.793569803238
#
# Trained 441 batches with current epoch cost: 227.90852543711662
# At batch: 441, the training accuracy is: 81.0%
# At batch: 441, the test accuracy is: 81.0%
# Current run time is: 5331.881126880646
#
# Epoch 9 completed out of: 30 loss: 281.023963332 , time: 560.0515716075897
#
# At end of epoch: 9, the training accuracy in batch is: 81.0%
# At end of epoch: 9, the test accuracy is: 82.6%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003]
# Total time taken for current epoch : 599.954683
#
# -------Running Epoch:10-------
# Trained 1 batches with current epoch cost: 0.3686111569404602
# At batch: 1, the training accuracy is: 86.0%
# At batch: 1, the test accuracy is: 83.0%
# Current run time is: 5483.768820285797
#
# Trained 111 batches with current epoch cost: 54.07699251174927
# At batch: 111, the training accuracy is: 82.0%
# At batch: 111, the test accuracy is: 80.0%
# Current run time is: 5596.084012508392
#
# Trained 221 batches with current epoch cost: 107.19090384244919
# At batch: 221, the training accuracy is: 81.0%
# At batch: 221, the test accuracy is: 80.0%
# Current run time is: 5719.834740400314
#
# Trained 331 batches with current epoch cost: 159.30695113539696
# At batch: 331, the training accuracy is: 81.0%
# At batch: 331, the test accuracy is: 81.0%
# Current run time is: 5822.367827415466
#
# Trained 441 batches with current epoch cost: 211.43637588620186
# At batch: 441, the training accuracy is: 84.0%
# At batch: 441, the test accuracy is: 80.0%
# Current run time is: 5926.090187072754
#
# Epoch 10 completed out of: 30 loss: 262.973309457 , time: 556.148001909256
#
# At end of epoch: 10, the training accuracy in batch is: 84.0%
# At end of epoch: 10, the test accuracy is: 83.9%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387]
# Total time taken for current epoch : 596.420846
#
# -------Running Epoch:11-------
# Trained 1 batches with current epoch cost: 0.38789740204811096
# At batch: 1, the training accuracy is: 87.0%
# At batch: 1, the test accuracy is: 81.0%
# Current run time is: 6080.054635286331
#
# Trained 111 batches with current epoch cost: 53.165412336587906
# At batch: 111, the training accuracy is: 90.0%
# At batch: 111, the test accuracy is: 78.0%
# Current run time is: 6190.209157943726
#
# Trained 221 batches with current epoch cost: 103.0519926995039
# At batch: 221, the training accuracy is: 86.0%
# At batch: 221, the test accuracy is: 85.0%
# Current run time is: 6299.913084983826
#
# Trained 331 batches with current epoch cost: 150.93898482620716
# At batch: 331, the training accuracy is: 90.0%
# At batch: 331, the test accuracy is: 82.0%
# Current run time is: 6411.146430492401
#
# Trained 441 batches with current epoch cost: 198.04318027198315
# At batch: 441, the training accuracy is: 93.0%
# At batch: 441, the test accuracy is: 83.0%
# Current run time is: 6521.218120336533
#
# Epoch 11 completed out of: 30 loss: 244.996234551 , time: 550.5662286281586
#
# At end of epoch: 11, the training accuracy in batch is: 93.0%
# At end of epoch: 11, the test accuracy is: 85.3%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003]
# Total time taken for current epoch : 587.905855
#
# -------Running Epoch:12-------
# Trained 1 batches with current epoch cost: 0.35052549839019775
# At batch: 1, the training accuracy is: 90.0%
# At batch: 1, the test accuracy is: 87.0%
# Current run time is: 6667.872241258621
#
# Trained 111 batches with current epoch cost: 45.514824256300926
# At batch: 111, the training accuracy is: 93.0%
# At batch: 111, the test accuracy is: 84.0%
# Current run time is: 6768.799111127853
#
# Trained 221 batches with current epoch cost: 89.65613651275635
# At batch: 221, the training accuracy is: 91.0%
# At batch: 221, the test accuracy is: 86.0%
# Current run time is: 6875.466862201691
#
# Trained 331 batches with current epoch cost: 132.8886083215475
# At batch: 331, the training accuracy is: 83.0%
# At batch: 331, the test accuracy is: 86.0%
# Current run time is: 6976.658470153809
#
# Trained 441 batches with current epoch cost: 174.74296189844608
# At batch: 441, the training accuracy is: 90.0%
# At batch: 441, the test accuracy is: 85.0%
# Current run time is: 7077.973082304001
#
# Epoch 12 completed out of: 30 loss: 218.165882289 , time: 511.8951873779297
#
# At end of epoch: 12, the training accuracy in batch is: 90.0%
# At end of epoch: 12, the test accuracy is: 87.3%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003]
# Total time taken for current epoch : 548.649428
#
# -------Running Epoch:13-------
# Trained 1 batches with current epoch cost: 0.3304044306278229
# At batch: 1, the training accuracy is: 87.0%
# At batch: 1, the test accuracy is: 85.0%
# Current run time is: 7216.551251173019
#
# Trained 111 batches with current epoch cost: 40.89915689826012
# At batch: 111, the training accuracy is: 85.0%
# At batch: 111, the test accuracy is: 88.0%
# Current run time is: 7327.059371471405
#
# Trained 221 batches with current epoch cost: 80.73916891217232
# At batch: 221, the training accuracy is: 89.0%
# At batch: 221, the test accuracy is: 84.0%
# Current run time is: 7438.8381469249725
#
# Trained 331 batches with current epoch cost: 119.6859251409769
# At batch: 331, the training accuracy is: 91.0%
# At batch: 331, the test accuracy is: 88.0%
# Current run time is: 7549.859641075134
#
# Trained 441 batches with current epoch cost: 160.4851967394352
# At batch: 441, the training accuracy is: 88.0%
# At batch: 441, the test accuracy is: 86.0%
# Current run time is: 7661.069384098053
#
# Epoch 13 completed out of: 30 loss: 197.473117009 , time: 569.5673387050629
#
# At end of epoch: 13, the training accuracy in batch is: 88.0%
# At end of epoch: 13, the test accuracy is: 87.8%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001]
# Total time taken for current epoch : 608.997958
#
# -------Running Epoch:14-------
# Trained 1 batches with current epoch cost: 0.36020562052726746
# At batch: 1, the training accuracy is: 90.0%
# At batch: 1, the test accuracy is: 90.0%
# Current run time is: 7825.542720079422
#
# Trained 111 batches with current epoch cost: 37.89338409900665
# At batch: 111, the training accuracy is: 90.0%
# At batch: 111, the test accuracy is: 88.0%
# Current run time is: 12283.116275787354
#
# Trained 221 batches with current epoch cost: 75.02887097001076
# At batch: 221, the training accuracy is: 86.0%
# At batch: 221, the test accuracy is: 87.0%
# Current run time is: 12385.581873893738
#
# Trained 331 batches with current epoch cost: 112.31804136931896
# At batch: 331, the training accuracy is: 85.0%
# At batch: 331, the test accuracy is: 84.0%
# Current run time is: 12484.664673805237
#
# Trained 441 batches with current epoch cost: 150.04030936956406
# At batch: 441, the training accuracy is: 91.0%
# At batch: 441, the test accuracy is: 91.0%
# Current run time is: 12583.556954622269
#
# Epoch 14 completed out of: 30 loss: 185.227656737 , time: 4857.818996429443
#
# At end of epoch: 14, the training accuracy in batch is: 91.0%
# At end of epoch: 14, the test accuracy is: 88.8%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876]
# Total time taken for current epoch : 4893.784328
#
# -------Running Epoch:15-------
# Trained 1 batches with current epoch cost: 0.3243337571620941
# At batch: 1, the training accuracy is: 86.0%
# At batch: 1, the test accuracy is: 88.0%
# Current run time is: 12719.34709739685
#
# Trained 111 batches with current epoch cost: 32.22569265961647
# At batch: 111, the training accuracy is: 93.0%
# At batch: 111, the test accuracy is: 89.0%
# Current run time is: 12818.996108055115
#
# Trained 221 batches with current epoch cost: 66.24203635752201
# At batch: 221, the training accuracy is: 89.0%
# At batch: 221, the test accuracy is: 85.0%
# Current run time is: 12919.468003511429
#
# Trained 331 batches with current epoch cost: 100.59782584756613
# At batch: 331, the training accuracy is: 94.0%
# At batch: 331, the test accuracy is: 87.0%
# Current run time is: 13019.605588197708
#
# Trained 441 batches with current epoch cost: 134.9577650204301
# At batch: 441, the training accuracy is: 92.0%
# At batch: 441, the test accuracy is: 88.0%
# Current run time is: 13120.283038377762
#
# Epoch 15 completed out of: 30 loss: 169.320753656 , time: 502.15049266815186
#
# At end of epoch: 15, the training accuracy in batch is: 92.0%
# At end of epoch: 15, the test accuracy is: 90.1%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998]
# Total time taken for current epoch : 538.809131
#
# -------Running Epoch:16-------
# Trained 1 batches with current epoch cost: 0.20485641062259674
# At batch: 1, the training accuracy is: 94.0%
# At batch: 1, the test accuracy is: 90.0%
# Current run time is: 13258.072793960571
#
# Trained 111 batches with current epoch cost: 33.67839677631855
# At batch: 111, the training accuracy is: 91.0%
# At batch: 111, the test accuracy is: 88.0%
# Current run time is: 13358.75696182251
#
# Trained 221 batches with current epoch cost: 64.44892740249634
# At batch: 221, the training accuracy is: 89.0%
# At batch: 221, the test accuracy is: 88.0%
# Current run time is: 13459.826047420502
#
# Trained 331 batches with current epoch cost: 95.42475855350494
# At batch: 331, the training accuracy is: 92.0%
# At batch: 331, the test accuracy is: 92.0%
# Current run time is: 13560.22555065155
#
# Trained 441 batches with current epoch cost: 127.31862109899521
# At batch: 441, the training accuracy is: 88.0%
# At batch: 441, the test accuracy is: 92.0%
# Current run time is: 13660.608512163162
#
# Epoch 16 completed out of: 30 loss: 158.222752661 , time: 503.51912474632263
#
# At end of epoch: 16, the training accuracy in batch is: 88.0%
# At end of epoch: 16, the test accuracy is: 89.8%
# Total time taken for current epoch : 538.958528
#
# -------Running Epoch:17-------
# Trained 1 batches with current epoch cost: 0.27711907029151917
# At batch: 1, the training accuracy is: 89.0%
# At batch: 1, the test accuracy is: 91.0%
# Current run time is: 13797.030042648315
#
# Trained 111 batches with current epoch cost: 29.383629262447357
# At batch: 111, the training accuracy is: 94.0%
# At batch: 111, the test accuracy is: 91.0%
# Current run time is: 13901.943211078644
#
# Trained 221 batches with current epoch cost: 58.979674741625786
# At batch: 221, the training accuracy is: 94.0%
# At batch: 221, the test accuracy is: 92.0%
# Current run time is: 14005.853511571884
#
# Trained 331 batches with current epoch cost: 89.31829047948122
# At batch: 331, the training accuracy is: 92.0%
# At batch: 331, the test accuracy is: 87.0%
# Current run time is: 14108.43728518486
#
# Trained 441 batches with current epoch cost: 118.53751232475042
# At batch: 441, the training accuracy is: 89.0%
# At batch: 441, the test accuracy is: 90.0%
# Current run time is: 14214.617314815521
#
# Epoch 17 completed out of: 30 loss: 147.663615413 , time: 518.0565543174744
#
# At end of epoch: 17, the training accuracy in batch is: 89.0%
# At end of epoch: 17, the test accuracy is: 91.1%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002]
# Total time taken for current epoch : 557.185879
#
# -------Running Epoch:18-------
# Trained 1 batches with current epoch cost: 0.1925434172153473
# At batch: 1, the training accuracy is: 95.0%
# At batch: 1, the test accuracy is: 89.0%
# Current run time is: 14354.218513965607
#
# Trained 111 batches with current epoch cost: 28.368400253355503
# At batch: 111, the training accuracy is: 94.0%
# At batch: 111, the test accuracy is: 91.0%
# Current run time is: 14459.956229686737
#
# Trained 221 batches with current epoch cost: 56.660221233963966
# At batch: 221, the training accuracy is: 90.0%
# At batch: 221, the test accuracy is: 92.0%
# Current run time is: 14565.876882076263
#
# Trained 331 batches with current epoch cost: 84.0270237326622
# At batch: 331, the training accuracy is: 94.0%
# At batch: 331, the test accuracy is: 91.0%
# Current run time is: 14676.559194087982
#
# Trained 441 batches with current epoch cost: 109.61771123111248
# At batch: 441, the training accuracy is: 96.0%
# At batch: 441, the test accuracy is: 93.0%
# Current run time is: 14787.164062023163
#
# Epoch 18 completed out of: 30 loss: 136.071219131 , time: 540.4742510318756
#
# At end of epoch: 18, the training accuracy in batch is: 96.0%
# At end of epoch: 18, the test accuracy is: 92.5%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002]
# Total time taken for current epoch : 582.403151
#
# -------Running Epoch:19-------
# Trained 1 batches with current epoch cost: 0.16704212129116058
# At batch: 1, the training accuracy is: 94.0%
# At batch: 1, the test accuracy is: 91.0%
# Current run time is: 14936.731648921967
#
# Trained 111 batches with current epoch cost: 25.643782779574394
# At batch: 111, the training accuracy is: 95.0%
# At batch: 111, the test accuracy is: 94.0%
# Current run time is: 15041.968037605286
#
# Trained 221 batches with current epoch cost: 50.543944880366325
# At batch: 221, the training accuracy is: 95.0%
# At batch: 221, the test accuracy is: 95.0%
# Current run time is: 15143.149210453033
#
# Trained 331 batches with current epoch cost: 75.1503531858325
# At batch: 331, the training accuracy is: 96.0%
# At batch: 331, the test accuracy is: 92.0%
# Current run time is: 15246.237751960754
#
# Trained 441 batches with current epoch cost: 100.44226692989469
# At batch: 441, the training accuracy is: 93.0%
# At batch: 441, the test accuracy is: 92.0%
# Current run time is: 15353.503925800323
#
# Epoch 19 completed out of: 30 loss: 125.100971889 , time: 519.5278496742249
#
# At end of epoch: 19, the training accuracy in batch is: 93.0%
# At end of epoch: 19, the test accuracy is: 93.9%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998]
# Total time taken for current epoch : 557.710728
#
# -------Running Epoch:20-------
# Trained 1 batches with current epoch cost: 0.13036981225013733
# At batch: 1, the training accuracy is: 97.0%
# At batch: 1, the test accuracy is: 94.0%
# Current run time is: 15494.382318258286
#
# Trained 111 batches with current epoch cost: 23.370823979377747
# At batch: 111, the training accuracy is: 97.0%
# At batch: 111, the test accuracy is: 90.0%
# Current run time is: 15600.52375125885
#
# Trained 221 batches with current epoch cost: 48.096541330218315
# At batch: 221, the training accuracy is: 93.0%
# At batch: 221, the test accuracy is: 93.0%
# Current run time is: 15704.313285112381
#
# Trained 331 batches with current epoch cost: 71.99027329683304
# At batch: 331, the training accuracy is: 94.0%
# At batch: 331, the test accuracy is: 92.0%
# Current run time is: 15813.742724657059
#
# Trained 441 batches with current epoch cost: 95.02808389812708
# At batch: 441, the training accuracy is: 96.0%
# At batch: 441, the test accuracy is: 96.0%
# Current run time is: 15916.349036216736
#
# Epoch 20 completed out of: 30 loss: 117.643314272 , time: 525.9987819194794
#
# At end of epoch: 20, the training accuracy in batch is: 96.0%
# At end of epoch: 20, the test accuracy is: 94.1%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998, 0.94059998]
# Total time taken for current epoch : 565.259833
#
# -------Running Epoch:21-------
# Trained 1 batches with current epoch cost: 0.15941554307937622
# At batch: 1, the training accuracy is: 94.0%
# At batch: 1, the test accuracy is: 92.0%
# Current run time is: 16059.71851015091
#
# Trained 111 batches with current epoch cost: 20.790024545043707
# At batch: 111, the training accuracy is: 97.0%
# At batch: 111, the test accuracy is: 94.0%
# Current run time is: 16165.491627931595
#
# Trained 221 batches with current epoch cost: 42.94362245127559
# At batch: 221, the training accuracy is: 92.0%
# At batch: 221, the test accuracy is: 96.0%
# Current run time is: 16270.543154716492
#
# Trained 331 batches with current epoch cost: 64.11141276732087
# At batch: 331, the training accuracy is: 98.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 16384.505692243576
#
# Trained 441 batches with current epoch cost: 83.9352004379034
# At batch: 441, the training accuracy is: 95.0%
# At batch: 441, the test accuracy is: 96.0%
# Current run time is: 16493.565089941025
#
# Epoch 21 completed out of: 30 loss: 104.498987213 , time: 543.1407694816589
#
# At end of epoch: 21, the training accuracy in batch is: 95.0%
# At end of epoch: 21, the test accuracy is: 94.2%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998, 0.94059998, 0.94209999]
# Total time taken for current epoch : 585.554053
#
# -------Running Epoch:22-------
# Trained 1 batches with current epoch cost: 0.11282818019390106
# At batch: 1, the training accuracy is: 97.0%
# At batch: 1, the test accuracy is: 90.0%
# Current run time is: 16645.19430088997
#
# Trained 111 batches with current epoch cost: 20.037253212183714
# At batch: 111, the training accuracy is: 91.0%
# At batch: 111, the test accuracy is: 94.0%
# Current run time is: 16749.4092502594
#
# Trained 221 batches with current epoch cost: 39.80986763909459
# At batch: 221, the training accuracy is: 96.0%
# At batch: 221, the test accuracy is: 96.0%
# Current run time is: 16854.891499757767
#
# Trained 331 batches with current epoch cost: 58.75403783097863
# At batch: 331, the training accuracy is: 94.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 16962.87104868889
#
# Trained 441 batches with current epoch cost: 77.5825015231967
# At batch: 441, the training accuracy is: 91.0%
# At batch: 441, the test accuracy is: 93.0%
# Current run time is: 17066.29208946228
#
# Epoch 22 completed out of: 30 loss: 96.7349287942 , time: 523.8401064872742
#
# At end of epoch: 22, the training accuracy in batch is: 91.0%
# At end of epoch: 22, the test accuracy is: 95.5%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998, 0.94059998, 0.94209999, 0.95490003]
# Total time taken for current epoch : 564.803727
#
# -------Running Epoch:23-------
# Trained 1 batches with current epoch cost: 0.16131088137626648
# At batch: 1, the training accuracy is: 97.0%
# At batch: 1, the test accuracy is: 93.0%
# Current run time is: 17209.89528107643
#
# Trained 111 batches with current epoch cost: 18.485891729593277
# At batch: 111, the training accuracy is: 98.0%
# At batch: 111, the test accuracy is: 96.0%
# Current run time is: 17314.122092485428
#
# Trained 221 batches with current epoch cost: 35.36652899906039
# At batch: 221, the training accuracy is: 95.0%
# At batch: 221, the test accuracy is: 94.0%
# Current run time is: 17418.38960313797
#
# Trained 331 batches with current epoch cost: 53.5800561234355
# At batch: 331, the training accuracy is: 95.0%
# At batch: 331, the test accuracy is: 96.0%
# Current run time is: 17524.70917582512
#
# Trained 441 batches with current epoch cost: 70.72524780407548
# At batch: 441, the training accuracy is: 94.0%
# At batch: 441, the test accuracy is: 96.0%
# Current run time is: 17632.921261548996
#
# Epoch 23 completed out of: 30 loss: 87.8749695979 , time: 532.1437184810638
#
# At end of epoch: 23, the training accuracy in batch is: 94.0%
# At end of epoch: 23, the test accuracy is: 94.9%
# Total time taken for current epoch : 582.674430
#
# -------Running Epoch:24-------
# Trained 1 batches with current epoch cost: 0.11133847385644913
# At batch: 1, the training accuracy is: 97.0%
# At batch: 1, the test accuracy is: 95.0%
# Current run time is: 17793.121613025665
#
# Trained 111 batches with current epoch cost: 15.745556604117155
# At batch: 111, the training accuracy is: 90.0%
# At batch: 111, the test accuracy is: 91.0%
# Current run time is: 17911.47306370735
#
# Trained 221 batches with current epoch cost: 32.964385110884905
# At batch: 221, the training accuracy is: 94.0%
# At batch: 221, the test accuracy is: 95.0%
# Current run time is: 18028.291451215744
#
# Trained 331 batches with current epoch cost: 48.643711909651756
# At batch: 331, the training accuracy is: 96.0%
# At batch: 331, the test accuracy is: 96.0%
# Current run time is: 18136.46520590782
#
# Trained 441 batches with current epoch cost: 62.87948429211974
# At batch: 441, the training accuracy is: 98.0%
# At batch: 441, the test accuracy is: 95.0%
# Current run time is: 18246.644150018692
#
# Epoch 24 completed out of: 30 loss: 78.1219111942 , time: 560.7072455883026
#
# At end of epoch: 24, the training accuracy in batch is: 98.0%
# At end of epoch: 24, the test accuracy is: 96.0%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998, 0.94059998, 0.94209999, 0.95490003, 0.94889998, 0.95950001]
# Total time taken for current epoch : 599.836378
#
# -------Running Epoch:25-------
# Trained 1 batches with current epoch cost: 0.15080761909484863
# At batch: 1, the training accuracy is: 95.0%
# At batch: 1, the test accuracy is: 96.0%
# Current run time is: 18392.56578564644
#
# Trained 111 batches with current epoch cost: 12.773337427526712
# At batch: 111, the training accuracy is: 94.0%
# At batch: 111, the test accuracy is: 99.0%
# Current run time is: 18499.08817911148
#
# Trained 221 batches with current epoch cost: 27.499857896007597
# At batch: 221, the training accuracy is: 97.0%
# At batch: 221, the test accuracy is: 95.0%
# Current run time is: 18606.261212587357
#
# Trained 331 batches with current epoch cost: 42.26021990273148
# At batch: 331, the training accuracy is: 98.0%
# At batch: 331, the test accuracy is: 94.0%
# Current run time is: 18723.014726161957
#
# Trained 441 batches with current epoch cost: 56.90060965809971
# At batch: 441, the training accuracy is: 97.0%
# At batch: 441, the test accuracy is: 97.0%
# Current run time is: 18837.448282003403
#
# Epoch 25 completed out of: 30 loss: 70.4968964169 , time: 551.5950772762299
#
# At end of epoch: 25, the training accuracy in batch is: 97.0%
# At end of epoch: 25, the test accuracy is: 96.2%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998, 0.94059998, 0.94209999, 0.95490003, 0.94889998, 0.95950001, 0.96200001]
# Total time taken for current epoch : 588.787710
#
# -------Running Epoch:26-------
# Trained 1 batches with current epoch cost: 0.09867145866155624
# At batch: 1, the training accuracy is: 96.0%
# At batch: 1, the test accuracy is: 96.0%
# Current run time is: 18981.368192195892
#
# Trained 111 batches with current epoch cost: 12.037562802433968
# At batch: 111, the training accuracy is: 98.0%
# At batch: 111, the test accuracy is: 98.0%
# Current run time is: 19084.54847073555
#
# Trained 221 batches with current epoch cost: 25.193272879347205
# At batch: 221, the training accuracy is: 96.0%
# At batch: 221, the test accuracy is: 97.0%
# Current run time is: 19192.70847249031
#
# Trained 331 batches with current epoch cost: 38.194173655472696
# At batch: 331, the training accuracy is: 96.0%
# At batch: 331, the test accuracy is: 99.0%
# Current run time is: 19300.256139993668
#
# Trained 441 batches with current epoch cost: 50.37239079643041
# At batch: 441, the training accuracy is: 98.0%
# At batch: 441, the test accuracy is: 98.0%
# Current run time is: 19409.799478292465
#
# Epoch 26 completed out of: 30 loss: 62.5660631154 , time: 538.8854787349701
#
# At end of epoch: 26, the training accuracy in batch is: 98.0%
# At end of epoch: 26, the test accuracy is: 97.0%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998, 0.94059998, 0.94209999, 0.95490003, 0.94889998, 0.95950001, 0.96200001, 0.96960002]
# Total time taken for current epoch : 584.701113
#
# -------Running Epoch:27-------
# Trained 1 batches with current epoch cost: 0.1636328548192978
# At batch: 1, the training accuracy is: 97.0%
# At batch: 1, the test accuracy is: 97.0%
# Current run time is: 19566.01787829399
#
# Trained 111 batches with current epoch cost: 11.617877211421728
# At batch: 111, the training accuracy is: 98.0%
# At batch: 111, the test accuracy is: 99.0%
# Current run time is: 19673.077129602432
#
# Trained 221 batches with current epoch cost: 21.8803517408669
# At batch: 221, the training accuracy is: 96.0%
# At batch: 221, the test accuracy is: 98.0%
# Current run time is: 19781.432856559753
#
# Trained 331 batches with current epoch cost: 33.27426314819604
# At batch: 331, the training accuracy is: 99.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 19897.21769785881
#
# Trained 441 batches with current epoch cost: 46.59513029176742
# At batch: 441, the training accuracy is: 97.0%
# At batch: 441, the test accuracy is: 95.0%
# Current run time is: 20007.1757543087
#
# Epoch 27 completed out of: 30 loss: 57.5496847061 , time: 550.7852830886841
#
# At end of epoch: 27, the training accuracy in batch is: 97.0%
# At end of epoch: 27, the test accuracy is: 97.1%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998, 0.94059998, 0.94209999, 0.95490003, 0.94889998, 0.95950001, 0.96200001, 0.96960002, 0.97119999]
# Total time taken for current epoch : 594.472955
#
# -------Running Epoch:28-------
# Trained 1 batches with current epoch cost: 0.026158947497606277
# At batch: 1, the training accuracy is: 100.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 20160.780498981476
#
# Trained 111 batches with current epoch cost: 9.533610118553042
# At batch: 111, the training accuracy is: 99.0%
# At batch: 111, the test accuracy is: 98.0%
# Current run time is: 20266.774955034256
#
# Trained 221 batches with current epoch cost: 20.949757555499673
# At batch: 221, the training accuracy is: 99.0%
# At batch: 221, the test accuracy is: 97.0%
# Current run time is: 20372.81598854065
#
# Trained 331 batches with current epoch cost: 31.556944743730128
# At batch: 331, the training accuracy is: 95.0%
# At batch: 331, the test accuracy is: 98.0%
# Current run time is: 20480.09739422798
#
# Trained 441 batches with current epoch cost: 41.21748482249677
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 98.0%
# Current run time is: 20584.62677049637
#
# Epoch 28 completed out of: 30 loss: 51.4656344531 , time: 528.7727563381195
#
# At end of epoch: 28, the training accuracy in batch is: 99.0%
# At end of epoch: 28, the test accuracy is: 97.0%
# Total time taken for current epoch : 565.577969
#
# -------Running Epoch:29-------
# Trained 1 batches with current epoch cost: 0.13978713750839233
# At batch: 1, the training accuracy is: 97.0%
# At batch: 1, the test accuracy is: 100.0%
# Current run time is: 20726.06331062317
#
# Trained 111 batches with current epoch cost: 9.610421040095389
# At batch: 111, the training accuracy is: 97.0%
# At batch: 111, the test accuracy is: 97.0%
# Current run time is: 20838.9973256588
#
# Trained 221 batches with current epoch cost: 19.104778892360628
# At batch: 221, the training accuracy is: 99.0%
# At batch: 221, the test accuracy is: 96.0%
# Current run time is: 20959.438987970352
#
# Trained 331 batches with current epoch cost: 30.474129407666624
# At batch: 331, the training accuracy is: 96.0%
# At batch: 331, the test accuracy is: 99.0%
# Current run time is: 21082.626431941986
#
# Trained 441 batches with current epoch cost: 40.549060684628785
# At batch: 441, the training accuracy is: 100.0%
# At batch: 441, the test accuracy is: 98.0%
# Current run time is: 21206.337612628937
#
# Epoch 29 completed out of: 30 loss: 50.2513377471 , time: 587.6906337738037
#
# At end of epoch: 29, the training accuracy in batch is: 100.0%
# At end of epoch: 29, the test accuracy is: 97.2%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998, 0.94059998, 0.94209999, 0.95490003, 0.94889998, 0.95950001, 0.96200001, 0.96960002, 0.97119999, 0.97000003, 0.97180003]
# Total time taken for current epoch : 631.320928
#
# -------Running Epoch:30-------
# Trained 1 batches with current epoch cost: 0.03591864928603172
# At batch: 1, the training accuracy is: 100.0%
# At batch: 1, the test accuracy is: 98.0%
# Current run time is: 21357.742547512054
#
# Trained 111 batches with current epoch cost: 9.150139077566564
# At batch: 111, the training accuracy is: 98.0%
# At batch: 111, the test accuracy is: 97.0%
# Current run time is: 21465.99133992195
#
# Trained 221 batches with current epoch cost: 18.543757514096797
# At batch: 221, the training accuracy is: 98.0%
# At batch: 221, the test accuracy is: 98.0%
# Current run time is: 21581.48138141632
#
# Trained 331 batches with current epoch cost: 27.8898186837323
# At batch: 331, the training accuracy is: 97.0%
# At batch: 331, the test accuracy is: 97.0%
# Current run time is: 21693.888956546783
#
# Trained 441 batches with current epoch cost: 38.21537077007815
# At batch: 441, the training accuracy is: 99.0%
# At batch: 441, the test accuracy is: 98.0%
# Current run time is: 21799.749920129776
#
# Epoch 30 completed out of: 30 loss: 47.7483269363 , time: 551.5773153305054
#
# At end of epoch: 30, the training accuracy in batch is: 99.0%
# At end of epoch: 30, the test accuracy is: 97.2%
# [0.31729999, 0.4772, 0.59939998, 0.68010002, 0.72000003, 0.7816, 0.79079998, 0.80909997, 0.82560003, 0.8387, 0.85290003, 0.87300003, 0.87760001, 0.8876, 0.90109998, 0.89829999, 0.91140002, 0.92540002, 0.93879998, 0.94059998, 0.94209999, 0.95490003, 0.94889998, 0.95950001, 0.96200001, 0.96960002, 0.97119999, 0.97000003, 0.97180003, 0.97219998]
# Total time taken for current epoch : 594.688003
#
# At final epoch: 30, the test accuracy is: 97.2%, with cost 0.08031024038791656
# Total time taken for run : 21990.441102

# %% [markdown]
# # Restoring model
# Here the model is restored and the values in the report match the recovered ones.

# %%
def print_acc(rnn_size,epochs):
    
    acc_test_list = []
    acc_train_list = []
    cost_train_list = []
    cost_test_list =[]
    b_size = 1000
    num_train = len(mnist.train.labels)
    num_test = len(mnist.test.labels)
    
    # Comment out here to use whole training set!
    num_train = len(mnist.train.labels[:10000,:])
    n_batches = num_train/b_size
    count = 0
    i = 0
    start = time.time()
    while i < num_train:
        print('Processing batch number {} of {}.'.format(count+1,n_batches))
        # The ending index for the next batch is denoted j.
        j = min(i + b_size, num_train)
        
        if j<= num_test:
            
            # Get the images from the test-set between index i and j.
            images_test = mnist.test.images.reshape((-1, 784, 1))[i:j, :]

            # Get the associated labels.
            labels_test = mnist.test.labels[i:j, :]

            acc_test, cost_test = sess.run([accuracy,cost],feed_dict = {x: binarize(images_test), y: labels_test})
            #print(cost_test)

            acc_test_list.append(acc_test)
            cost_test_list.append(cost_test)
        images_train = mnist.train.images.reshape((-1, 784, 1))[i:j, :]

        # Get the associated labels.
        labels_test = mnist.train.labels[i:j, :]

        acc_train,cost_train = sess.run([accuracy,cost],feed_dict = {x: binarize(images_train), y: labels_test})
        acc_train_list.append(acc_train)
        cost_train_list.append(cost_train)
        i = j
        count +=1
        
    #print(cost)
    #print(time.time()-start)
    print('\n')
    
    total_acc_train = sum(acc_train_list)/len(acc_train_list)
    total_acc_test = sum(acc_test_list)/len(acc_test_list)
    total_cost_train = sum(cost_train_list)/len(cost_train_list)
    total_cost_test = sum(cost_test_list)/len(cost_test_list)
    #print(total_acc)
    #total_cost = sum(cost)/len(cost)
    print(time.time()-start)
    print('The training accuracy for the 3 layer {} unit GRU model is {:.1%} after {} epochs'.format(rnn_size,total_acc_train,epochs))
    print('The training cost for the 3 layer {} unit GRU model is {} after {} epochs \n'.format(rnn_size,total_cost_train,epochs))
    print('The test accuracy for the 3 layer {} unit GRU model is {:.1%} after {} epochs'.format(rnn_size,total_acc_test,epochs))
    print('The test cost for the 3 layer {} unit GRU model is {} after {} epochs \n'.format(rnn_size,total_cost_test,epochs))
    return(total_acc_train,total_acc_test)

# %%
save_MDir = 'models/3Layer_gru/'
save_model = os.path.join(save_MDir,'best_accuracy_3')
init = tf.global_variables_initializer()

# %%
sess= tf.Session()
sess.run(init)
saver2restore = tf.train.Saver()
saver2restore.restore(sess = sess, save_path= save_model)

# %%
print_acc(rnn_size=32, epochs = 30)
sess.close()
# Out:
# Processing batch number 1 of 55.0.
# Processing batch number 2 of 55.0.
# Processing batch number 3 of 55.0.
# Processing batch number 4 of 55.0.
# Processing batch number 5 of 55.0.
# Processing batch number 6 of 55.0.
# Processing batch number 7 of 55.0.
# Processing batch number 8 of 55.0.
# Processing batch number 9 of 55.0.
# Processing batch number 10 of 55.0.
# Processing batch number 11 of 55.0.
# Processing batch number 12 of 55.0.
# Processing batch number 13 of 55.0.
# Processing batch number 14 of 55.0.
# Processing batch number 15 of 55.0.
# Processing batch number 16 of 55.0.
# Processing batch number 17 of 55.0.
# Processing batch number 18 of 55.0.
# Processing batch number 19 of 55.0.
# Processing batch number 20 of 55.0.
# Processing batch number 21 of 55.0.
# Processing batch number 22 of 55.0.
# Processing batch number 23 of 55.0.
# Processing batch number 24 of 55.0.
# Processing batch number 25 of 55.0.
# Processing batch number 26 of 55.0.
# Processing batch number 27 of 55.0.
# Processing batch number 28 of 55.0.
# Processing batch number 29 of 55.0.
# Processing batch number 30 of 55.0.
# Processing batch number 31 of 55.0.
# Processing batch number 32 of 55.0.
# Processing batch number 33 of 55.0.
# Processing batch number 34 of 55.0.
# Processing batch number 35 of 55.0.
# Processing batch number 36 of 55.0.
# Processing batch number 37 of 55.0.
# Processing batch number 38 of 55.0.
# Processing batch number 39 of 55.0.
# Processing batch number 40 of 55.0.
# Processing batch number 41 of 55.0.
# Processing batch number 42 of 55.0.
# Processing batch number 43 of 55.0.
# Processing batch number 44 of 55.0.
# Processing batch number 45 of 55.0.
# Processing batch number 46 of 55.0.
# Processing batch number 47 of 55.0.
# Processing batch number 48 of 55.0.
# Processing batch number 49 of 55.0.
# Processing batch number 50 of 55.0.
# Processing batch number 51 of 55.0.
# Processing batch number 52 of 55.0.
# Processing batch number 53 of 55.0.
# Processing batch number 54 of 55.0.
# Processing batch number 55 of 55.0.
#
#
# 173.13800477981567
# The training accuracy for the 3 layer 32 unit GRU model is 97.5% after 30 epochs
# The training cost for the 3 layer 32 unit GRU model is 0.0765998597849499 after 30 epochs
#
# The test accuracy for the 3 layer 32 unit GRU model is 97.2% after 30 epochs
# The test cost for the 3 layer 32 unit GRU model is 0.08031027801334858 after 30 epochs

# %%
print_acc(rnn_size=32, epochs = 30)
sess.close()
# Out:
# Processing batch number 1 of 10.0.
# Processing batch number 2 of 10.0.
# Processing batch number 3 of 10.0.
# Processing batch number 4 of 10.0.
# Processing batch number 5 of 10.0.
# Processing batch number 6 of 10.0.
# Processing batch number 7 of 10.0.
# Processing batch number 8 of 10.0.
# Processing batch number 9 of 10.0.
# Processing batch number 10 of 10.0.
#
#
# 46.34651732444763
# The training accuracy for the 3 layer 32 unit GRU model is 97.2% after 30 epochs
# The training cost for the 3 layer 32 unit GRU model is 0.08718579411506652 after 30 epochs
#
# The test accuracy for the 3 layer 32 unit GRU model is 97.2% after 30 epochs
# The test cost for the 3 layer 32 unit GRU model is 0.08031027801334858 after 30 epochs
