# %% [markdown]
# # Question 8 : Sarsa
# Copying the current network parameters to the target network every 5 episodes and acting $\epsilon$-greedily in target network.

# %% [markdown]
# # Running this file
# Run the until stopped and proceed as instucted

# %%
import sys
import math
import random
import pdb
import numpy as np
import tensorflow as tf
import gym
import time
import warnings
import matplotlib.pyplot as plt
import matplotlib
import os
from copy import deepcopy
warnings.filterwarnings('ignore')

# %%
def eps_greed(q,epsilon=0.05):
    u = np.random.uniform(0,1,1)
    if u <= epsilon:

        if np.random.uniform(0,1,1)>0.5:
            act = 0
        else:
            act = 1
    else:
        act = np.argmax(q)
        
    return act

# %%
# create a network that  will be used to take the loss.
def q_net_opt(state,action, weights, biases, q_target, alpha, discount = 0.99):

    hidden = tf.nn.relu(tf.matmul(state, weights['w1']) + biases['b1'])
    q = tf.matmul(hidden, weights['w2']) + biases['b2']

    qa = tf.reshape(tf.gather_nd(q, action), [-1, 1])
    diff = tf.square(q_target - qa) / 2
    loss = tf.reduce_mean(diff)
    opt = tf.train.AdamOptimizer(learning_rate=alpha).minimize(loss)
    return opt, q, loss

# %%
# create a network that  will be used to take the loss.
def q_target(next_state, weights, biases, reward,rand_states, discount = 0.99,epsilon = 0.05):
    
    hidden = tf.nn.relu(tf.matmul(next_state, weights['w1']) + biases['b1'])
    q_prime = tf.matmul(hidden, weights['w2']) + biases['b2']
    # act epsilon greediliy in target net
    u = np.random.uniform(0,1,1)
    if u <= epsilon:
        q_prime_max =  tf.reshape(tf.gather_nd(q_prime, rand_states), [-1, 1])
         
    else:
        q_prime_max = tf.reshape(tf.reduce_max(q_prime, reduction_indices=[1]), [-1, 1])

    delta = reward + 1   # don't boostrap if state is terminal
    target = reward + discount * tf.multiply(delta, tf.stop_gradient(q_prime_max))
    return target

# %%
# reference
def get_q_optimize2(state, next_state,action, alpha, reward, discount = 0.99):

    weights = {'w1': tf.Variable(tf.random_uniform([4, 100], 0, 0.01)),
               'w2': tf.Variable(tf.random_uniform([100, 2], 0, 0.01))}
    biases = {'b1': tf.Variable(tf.random_uniform([100], 0, 0.01)),
              'b2': tf.Variable(tf.random_uniform([2], 0, 0.01))}

    hidden = tf.nn.relu(tf.matmul(state, weights['w1']) + biases['b1'])
    q = tf.matmul(hidden, weights['w2']) + biases['b2']

    hidden = tf.nn.relu(tf.matmul(next_state, weights['w1']) + biases['b1'])
    q_prime = tf.matmul(hidden, weights['w2']) + biases['b2']

    #print(type(q_prime))
    #b = tf.select(q_prime>0.1)
    delta = reward + 1   # don't boostrap if state is terminal
    q_prime_max = tf.reshape(tf.reduce_max(q_prime, reduction_indices=[1]), [-1, 1])
    qa = tf.reshape(tf.gather_nd(q, action), [-1, 1])
    diff = tf.square(reward + discount * tf.multiply(delta, tf.stop_gradient(q_prime_max)) - qa) / 2
    loss = tf.reduce_mean(diff)
    #opt = tf.train.RMSPropOptimizer(alpha, 0.95, 0.0, 1e-7).minimize(loss)
    #hidden
    #opt = tf.train.RMSPropOptimizer(alpha, 0.99, 0.0, 1e-6).minimize(loss)
    opt = tf.train.AdamOptimizer(learning_rate=alpha).minimize(loss)
    return opt, q, loss

# %% [markdown]
# # Do not run these cells...
# Continue to load data below to load model and get return and length of episodes

# %%
# Training parameters
max_eps_length = 300
discount = 0.99
alpha = 0.001
n_episodes = 2000
freq = n_episodes/100
epsilon = 0.05
sample_episodes = 10
episode_lengths = []
episode_returns = []

# %%
# Need to save the model, weights and biases varibles

# Suggested Directory to use
save_MDir = 'new_models/A8/'


#create the directory if it does not exist already
if not os.path.exists(save_MDir):
    os.makedirs(save_MDir)

save_model = os.path.join(save_MDir,'sarsa_model')

# %%
q_weights = {'w1': tf.Variable(tf.random_uniform([4, 100], 0, 0.01)),
       'w2': tf.Variable(tf.random_uniform([100, 2], 0, 0.01))}
q_biases = {'b1': tf.Variable(tf.random_uniform([100], 0, 0.01)),
      'b2': tf.Variable(tf.random_uniform([2], 0, 0.01))}
qt_weights = {'w1': tf.Variable(tf.random_uniform([4, 100], 0, 0.01)),
       'w2': tf.Variable(tf.random_uniform([100, 2], 0, 0.01))}
qt_biases = {'b1': tf.Variable(tf.random_uniform([100], 0, 0.01)),
      'b2': tf.Variable(tf.random_uniform([2], 0, 0.01))}

# %%
# copy variables:
copy_w1 = qt_weights['w1'].assign(q_weights['w1'])
copy_w2 = qt_weights['w2'].assign(q_weights['w2'])
copy_b1 = qt_biases['b1'].assign(q_biases['b1'])
copy_b2 = qt_biases['b2'].assign(q_biases['b2'])

# %%
start = time.time()
replay_buffer = np.load("./replay_buffer_data.npy")
replay_buffer = replay_buffer[:1000,:]
batch_size = 64
sample_episodes = 15
n_episodes = 2000
freq = n_episodes/100
count = 0
counting = 0    
replay_count = 0
# for each episode in 2000 episodes we optimize the q values. 
#print('----Starting iteration number: {}----'.format(iteration+1))
#start_iteration = time.time()

episode_loss = []
total_episode_lengths = []
total_episode_returns = []
env = gym.make('CartPole-v0')
env._max_episode_steps = 300

state = tf.placeholder("float", [None, 4], name = 'state')
action = tf.placeholder(tf.int32, [None, 2], name = 'actions')
next_state = tf.placeholder("float", [None, 4], name = 'next_states')
reward = tf.placeholder("float", [None, 1], 'rewards')
target = tf.placeholder("float", [None,1],'target')
rand_states = tf.placeholder("float", [None,2],'rand_states')

optimize,q,loss = q_net_opt(state,action, q_weights, q_biases, target, alpha, discount = 0.99)
tar = q_target(next_state, qt_weights, qt_biases, reward,rand_states, discount = 0.99)
#optimize,q,loss = get_q_optimize2(state, next_state,action, alpha, reward, discount)

terminate_episode = False
init = tf.global_variables_initializer()
saver = tf.train.Saver(write_version=tf.train.SaverDef.V2)


with tf.Session() as sess:
    sess.run(init)

    for i_episode in range(n_episodes):
        #----------------------------------Here is where we copy
        if i_episode % 5 == 0:
            print('Copying variables at episode {}'.format(i_episode))
            sess.run([copy_w1,copy_w2,copy_b1,copy_b2])
            
        if i_episode % freq == 0:
            print('Now runnning episode:{}'.format(i_episode+1))
            print('Total run time so far is: {}'.format(time.time()-start))
        # Every 10 episodes we take 10 sample runs and report their average lengths
        if i_episode % freq == 0:
            
            sample_episode_lengths = []
            sample_episode_returns = []            
            for _ in range(sample_episodes):
                s = env.reset()
                for t in range(max_eps_length):
                    cur_q = sess.run(q, feed_dict={state:s.reshape(1,-1)})
                    a = eps_greed(cur_q)
                    s_prime,re,done,info = env.step(a)
                    

                    if done:
                        #print('episode finished')
                        re = -1
                        sample_episode_lengths.append(t+1)
                        sample_episode_returns.append(-1*discount**t)
                        break

                    s = s_prime
            total_episode_lengths.append(np.mean(sample_episode_lengths))
            total_episode_returns.append(np.mean(sample_episode_returns))


        s = env.reset()
        for t in range(max_eps_length):
            cur_q = sess.run(q, feed_dict={state:s.reshape(1,-1)})
            a = eps_greed(cur_q)
            s_prime,re,done,info = env.step(a)
#             if replay_count == 500:
#                 print(replay_buffer[:20,:])
            if done:
                re = -1
                #print(s_prime)
                replay_buffer[replay_count,:] = np.append(np.append(s.reshape(1,-1), np.asarray([a, re])), s_prime.reshape(1,-1))
                replay_count +=1
                if replay_count == replay_buffer.shape[0]:
                    replay_count =0
                episode_lengths.append(t+1)
                episode_returns.append(-1*discount**t)
                terminate_episode = True
                if i_episode % freq == 0:
                    print('For episode {} the length is: {}\n'.format( i_episode+1,t+1))
            else:
                re = 0
                replay_buffer[replay_count,:] = np.append(np.append(s.reshape(1,-1), np.asarray([a, re])), s_prime.reshape(1,-1))
                replay_count +=1
                if replay_count == replay_buffer.shape[0]:
                    replay_count =0
            
            # Now I need to put in the batch. ie copy orig data shuffle, take first 64 samples, dont  fprget to label actinos
            # optimize and repeat
            shuffled_data = deepcopy(replay_buffer)
            np.random.shuffle(shuffled_data)
            batch = shuffled_data[:batch_size,:]
            act = batch[:, 4].reshape(-1, 1)
            act = np.append(np.arange(len(act)).reshape(-1, 1), act, axis=1)
            rand_s =np.random.binomial(1, 0.5, 32).reshape(-1,1)
            rand_s = np.append(np.arange(len(rand_s)).reshape(-1, 1), rand_s, axis=1)
            
            qt_dict = {next_state: batch[:,-4:], reward : batch[:,5].reshape(-1,1), rand_states: rand_s}
            q_tar = sess.run(tar, qt_dict)
            #print(q_tar.shape)
            
            q_dict = {state : batch[:,:4],action:act,
                         reward : batch[:,5].reshape(-1,1), target: q_tar.reshape(-1,1)
                        }
            #this_dict = {state:s.reshape(-1,1), next_state:s_prime.reshape(-1,1), action:a, reward:re}
            opt, ls = sess.run([optimize,loss],q_dict)

            if  terminate_episode == True:
                count +=1
                terminate_episode = False
                break
            s = s_prime
            
            #if replay_count == 0:
            #print(replay_buffer[:100,:])
        if i_episode %freq == 0:
                episode_loss.append(ls)
        
    
    print('Saving model...')
    saver.save(sess= sess, save_path = save_model)

total_episode_lengths = np.asarray(total_episode_lengths).reshape(-1,1)
total_episode_returns = np.asarray(total_episode_returns).reshape(-1,1)
episode_loss = np.asarray(episode_loss).reshape(-1,1)

saved_data  = np.concatenate((total_episode_lengths, total_episode_returns, episode_loss), axis=1)
filename = './results/A8_results.csv'
#np.savetxt(filename, saved_data, delimiter=' ,')
print('Total run time is: {}'.format(time.time()-start))
# Out:
# [2017-04-07 22:04:02,247] Making new env: CartPole-v0
# Copying variables at episode 0
# Now runnning episode:1
# Total run time so far is: 1.438953161239624
# For episode 1 the length is: 10
#
# Copying variables at episode 5
# Copying variables at episode 10
# Copying variables at episode 15
# Copying variables at episode 20
# Now runnning episode:21
# Total run time so far is: 2.974951982498169
# For episode 21 the length is: 60
#
# Copying variables at episode 25
# Copying variables at episode 30
# Copying variables at episode 35
# Copying variables at episode 40
# Now runnning episode:41
# Total run time so far is: 10.98388671875
# For episode 41 the length is: 140
#
# Copying variables at episode 45
# Copying variables at episode 50
# Copying variables at episode 55
# Copying variables at episode 60
# Now runnning episode:61
# Total run time so far is: 18.103711128234863
# For episode 61 the length is: 121
#
# Copying variables at episode 65
# Copying variables at episode 70
# Copying variables at episode 75
# Copying variables at episode 80
# Now runnning episode:81
# Total run time so far is: 25.136043071746826
# For episode 81 the length is: 142
#
# Copying variables at episode 85
# Copying variables at episode 90
# Copying variables at episode 95
# Copying variables at episode 100
# Now runnning episode:101
# Total run time so far is: 34.399436235427856
# For episode 101 the length is: 111
#
# Copying variables at episode 105
# Copying variables at episode 110
# Copying variables at episode 115
# Copying variables at episode 120
# Now runnning episode:121
# Total run time so far is: 46.82488656044006
# For episode 121 the length is: 170
#
# Copying variables at episode 125
# Copying variables at episode 130
# Copying variables at episode 135
# Copying variables at episode 140
# Now runnning episode:141
# Total run time so far is: 56.087223529815674
# For episode 141 the length is: 131
#
# Copying variables at episode 145
# Copying variables at episode 150
# Copying variables at episode 155
# Copying variables at episode 160
# Now runnning episode:161
# Total run time so far is: 65.95634841918945
# For episode 161 the length is: 150
#
# Copying variables at episode 165
# Copying variables at episode 170
# Copying variables at episode 175
# Copying variables at episode 180
# Now runnning episode:181
# Total run time so far is: 77.14612793922424
# For episode 181 the length is: 144
#
# Copying variables at episode 185
# Copying variables at episode 190
# Copying variables at episode 195
# Copying variables at episode 200
# Now runnning episode:201
# Total run time so far is: 88.4180076122284
# For episode 201 the length is: 145
#
# Copying variables at episode 205
# Copying variables at episode 210
# Copying variables at episode 215
# Copying variables at episode 220
# Now runnning episode:221
# Total run time so far is: 100.96616744995117
# For episode 221 the length is: 145
#
# Copying variables at episode 225
# Copying variables at episode 230
# Copying variables at episode 235
# Copying variables at episode 240
# Now runnning episode:241
# Total run time so far is: 108.74445796012878
# For episode 241 the length is: 222
#
# Copying variables at episode 245
# Copying variables at episode 250
# Copying variables at episode 255
# Copying variables at episode 260
# Now runnning episode:261
# Total run time so far is: 121.79854035377502
# For episode 261 the length is: 35
#
# Copying variables at episode 265
# Copying variables at episode 270
# Copying variables at episode 275
# Copying variables at episode 280
# Now runnning episode:281
# Total run time so far is: 129.94994616508484
# For episode 281 the length is: 149
#
# Copying variables at episode 285
# Copying variables at episode 290
# Copying variables at episode 295
# Copying variables at episode 300
# Now runnning episode:301
# Total run time so far is: 141.54253578186035
# For episode 301 the length is: 201
#
# Copying variables at episode 305
# Copying variables at episode 310
# Copying variables at episode 315
# Copying variables at episode 320
# Now runnning episode:321
# Total run time so far is: 156.04045033454895
# For episode 321 the length is: 293
#
# Copying variables at episode 325
# Copying variables at episode 330
# Copying variables at episode 335
# Copying variables at episode 340
# Now runnning episode:341
# Total run time so far is: 169.7384374141693
# For episode 341 the length is: 106
#
# Copying variables at episode 345
# Copying variables at episode 350
# Copying variables at episode 355
# Copying variables at episode 360
# Now runnning episode:361
# Total run time so far is: 184.1783802509308
# For episode 361 the length is: 254
#
# Copying variables at episode 365
# Copying variables at episode 370
# Copying variables at episode 375
# Copying variables at episode 380
# Now runnning episode:381
# Total run time so far is: 200.14691925048828
# For episode 381 the length is: 300
#
# Copying variables at episode 385
# Copying variables at episode 390
# Copying variables at episode 395
# Copying variables at episode 400
# Now runnning episode:401
# Total run time so far is: 215.23750114440918
# For episode 401 the length is: 207
#
# Copying variables at episode 405
# Copying variables at episode 410
# Copying variables at episode 415
# Copying variables at episode 420
# Now runnning episode:421
# Total run time so far is: 232.84736824035645
# For episode 421 the length is: 179
#
# Copying variables at episode 425
# Copying variables at episode 430
# Copying variables at episode 435
# Copying variables at episode 440
# Now runnning episode:441
# Total run time so far is: 242.95230102539062
# For episode 441 the length is: 189
#
# Copying variables at episode 445
# Copying variables at episode 450
# Copying variables at episode 455
# Copying variables at episode 460
# Now runnning episode:461
# Total run time so far is: 255.69965386390686
# For episode 461 the length is: 262
#
# Copying variables at episode 465
# Copying variables at episode 470
# Copying variables at episode 475
# Copying variables at episode 480
# Now runnning episode:481
# Total run time so far is: 268.64607763290405
# For episode 481 the length is: 182
#
# Copying variables at episode 485
# Copying variables at episode 490
# Copying variables at episode 495
# Copying variables at episode 500
# Now runnning episode:501
# Total run time so far is: 277.81951212882996
# For episode 501 the length is: 145
#
# Copying variables at episode 505
# Copying variables at episode 510
# Copying variables at episode 515
# Copying variables at episode 520
# Now runnning episode:521
# Total run time so far is: 286.50065565109253
# For episode 521 the length is: 123
#
# Copying variables at episode 525
# Copying variables at episode 530
# Copying variables at episode 535
# Copying variables at episode 540
# Now runnning episode:541
# Total run time so far is: 295.3586378097534
# For episode 541 the length is: 97
#
# Copying variables at episode 545
# Copying variables at episode 550
# Copying variables at episode 555
# Copying variables at episode 560
# Now runnning episode:561
# Total run time so far is: 303.5317630767822
# For episode 561 the length is: 117
#
# Copying variables at episode 565
# Copying variables at episode 570
# Copying variables at episode 575
# Copying variables at episode 580
# Now runnning episode:581
# Total run time so far is: 312.41607904434204
# For episode 581 the length is: 239
#
# Copying variables at episode 585
# Copying variables at episode 590
# Copying variables at episode 595
# Copying variables at episode 600
# Now runnning episode:601
# Total run time so far is: 322.05129194259644
# For episode 601 the length is: 236
#
# Copying variables at episode 605
# Copying variables at episode 610
# Copying variables at episode 615
# Copying variables at episode 620
# Now runnning episode:621
# Total run time so far is: 336.32013392448425
# For episode 621 the length is: 185
#
# Copying variables at episode 625
# Copying variables at episode 630
# Copying variables at episode 635
# Copying variables at episode 640
# Now runnning episode:641
# Total run time so far is: 346.1149260997772
# For episode 641 the length is: 300
#
# Copying variables at episode 645
# Copying variables at episode 650
# Copying variables at episode 655
# Copying variables at episode 660
# Now runnning episode:661
# Total run time so far is: 359.0566437244415
# For episode 661 the length is: 177
#
# Copying variables at episode 665
# Copying variables at episode 670
# Copying variables at episode 675
# Copying variables at episode 680
# Now runnning episode:681
# Total run time so far is: 370.21932196617126
# For episode 681 the length is: 178
#
# Copying variables at episode 685
# Copying variables at episode 690
# Copying variables at episode 695
# Copying variables at episode 700
# Now runnning episode:701
# Total run time so far is: 381.80142641067505
# For episode 701 the length is: 202
#
# Copying variables at episode 705
# Copying variables at episode 710
# Copying variables at episode 715
# Copying variables at episode 720
# Now runnning episode:721
# Total run time so far is: 395.20978474617004
# For episode 721 the length is: 184
#
# Copying variables at episode 725
# Copying variables at episode 730
# Copying variables at episode 735
# Copying variables at episode 740
# Now runnning episode:741
# Total run time so far is: 412.72924423217773
# For episode 741 the length is: 300
#
# Copying variables at episode 745
# Copying variables at episode 750
# Copying variables at episode 755
# Copying variables at episode 760
# Now runnning episode:761
# Total run time so far is: 432.1051092147827
# For episode 761 the length is: 300
#
# Copying variables at episode 765
# Copying variables at episode 770
# Copying variables at episode 775
# Copying variables at episode 780
# Now runnning episode:781
# Total run time so far is: 449.8779456615448
# For episode 781 the length is: 300
#
# Copying variables at episode 785
# Copying variables at episode 790
# Copying variables at episode 795
# Copying variables at episode 800
# Now runnning episode:801
# Total run time so far is: 462.6530544757843
# For episode 801 the length is: 193
#
# Copying variables at episode 805
# Copying variables at episode 810
# Copying variables at episode 815
# Copying variables at episode 820
# Now runnning episode:821
# Total run time so far is: 477.7504074573517
# For episode 821 the length is: 260
#
# Copying variables at episode 825
# Copying variables at episode 830
# Copying variables at episode 835
# Copying variables at episode 840
# Now runnning episode:841
# Total run time so far is: 496.3663730621338
# For episode 841 the length is: 80
#
# Copying variables at episode 845
# Copying variables at episode 850
# Copying variables at episode 855
# Copying variables at episode 860
# Now runnning episode:861
# Total run time so far is: 514.7137064933777
# For episode 861 the length is: 134
#
# Copying variables at episode 865
# Copying variables at episode 870
# Copying variables at episode 875
# Copying variables at episode 880
# Now runnning episode:881
# Total run time so far is: 525.7939901351929
# For episode 881 the length is: 300
#
# Copying variables at episode 885
# Copying variables at episode 890
# Copying variables at episode 895
# Copying variables at episode 900
# Now runnning episode:901
# Total run time so far is: 538.0585970878601
# For episode 901 the length is: 300
#
# Copying variables at episode 905
# Copying variables at episode 910
# Copying variables at episode 915
# Copying variables at episode 920
# Now runnning episode:921
# Total run time so far is: 556.9526927471161
# For episode 921 the length is: 300
#
# Copying variables at episode 925
# Copying variables at episode 930
# Copying variables at episode 935
# Copying variables at episode 940
# Now runnning episode:941
# Total run time so far is: 571.8547515869141
# For episode 941 the length is: 136
#
# Copying variables at episode 945
# Copying variables at episode 950
# Copying variables at episode 955
# Copying variables at episode 960
# Now runnning episode:961
# Total run time so far is: 582.1758441925049
# For episode 961 the length is: 244
#
# Copying variables at episode 965
# Copying variables at episode 970
# Copying variables at episode 975
# Copying variables at episode 980
# Now runnning episode:981
# Total run time so far is: 597.9820611476898
# For episode 981 the length is: 300
#
# Copying variables at episode 985
# Copying variables at episode 990
# Copying variables at episode 995
# Copying variables at episode 1000
# Now runnning episode:1001
# Total run time so far is: 611.0631928443909
# For episode 1001 the length is: 177
#
# Copying variables at episode 1005
# Copying variables at episode 1010
# Copying variables at episode 1015
# Copying variables at episode 1020
# Now runnning episode:1021
# Total run time so far is: 623.8815939426422
# For episode 1021 the length is: 227
#
# Copying variables at episode 1025
# Copying variables at episode 1030
# Copying variables at episode 1035
# Copying variables at episode 1040
# Now runnning episode:1041
# Total run time so far is: 637.5976240634918
# For episode 1041 the length is: 178
#
# Copying variables at episode 1045
# Copying variables at episode 1050
# Copying variables at episode 1055
# Copying variables at episode 1060
# Now runnning episode:1061
# Total run time so far is: 650.891747713089
# For episode 1061 the length is: 158
#
# Copying variables at episode 1065
# Copying variables at episode 1070
# Copying variables at episode 1075
# Copying variables at episode 1080
# Now runnning episode:1081
# Total run time so far is: 668.6209330558777
# For episode 1081 the length is: 212
#
# Copying variables at episode 1085
# Copying variables at episode 1090
# Copying variables at episode 1095
# Copying variables at episode 1100
# Now runnning episode:1101
# Total run time so far is: 685.3045291900635
# For episode 1101 the length is: 173
#
# Copying variables at episode 1105
# Copying variables at episode 1110
# Copying variables at episode 1115
# Copying variables at episode 1120
# Now runnning episode:1121
# Total run time so far is: 698.3032667636871
# For episode 1121 the length is: 116
#
# Copying variables at episode 1125
# Copying variables at episode 1130
# Copying variables at episode 1135
# Copying variables at episode 1140
# Now runnning episode:1141
# Total run time so far is: 704.0045554637909
# For episode 1141 the length is: 109
#
# Copying variables at episode 1145
# Copying variables at episode 1150
# Copying variables at episode 1155
# Copying variables at episode 1160
# Now runnning episode:1161
# Total run time so far is: 711.0446772575378
# For episode 1161 the length is: 116
#
# Copying variables at episode 1165
# Copying variables at episode 1170
# Copying variables at episode 1175
# Copying variables at episode 1180
# Now runnning episode:1181
# Total run time so far is: 718.4829218387604
# For episode 1181 the length is: 96
#
# Copying variables at episode 1185
# Copying variables at episode 1190
# Copying variables at episode 1195
# Copying variables at episode 1200
# Now runnning episode:1201
# Total run time so far is: 725.7921853065491
# For episode 1201 the length is: 118
#
# Copying variables at episode 1205
# Copying variables at episode 1210
# Copying variables at episode 1215
# Copying variables at episode 1220
# Now runnning episode:1221
# Total run time so far is: 732.4798173904419
# For episode 1221 the length is: 110
#
# Copying variables at episode 1225
# Copying variables at episode 1230
# Copying variables at episode 1235
# Copying variables at episode 1240
# Now runnning episode:1241
# Total run time so far is: 739.6570563316345
# For episode 1241 the length is: 104
#
# Copying variables at episode 1245
# Copying variables at episode 1250
# Copying variables at episode 1255
# Copying variables at episode 1260
# Now runnning episode:1261
# Total run time so far is: 748.9980216026306
# For episode 1261 the length is: 158
#
# Copying variables at episode 1265
# Copying variables at episode 1270
# Copying variables at episode 1275
# Copying variables at episode 1280
# Now runnning episode:1281
# Total run time so far is: 757.9676630496979
# For episode 1281 the length is: 185
#
# Copying variables at episode 1285
# Copying variables at episode 1290
# Copying variables at episode 1295
# Copying variables at episode 1300
# Now runnning episode:1301
# Total run time so far is: 771.0776879787445
# For episode 1301 the length is: 300
#
# Copying variables at episode 1305
# Copying variables at episode 1310
# Copying variables at episode 1315
# Copying variables at episode 1320
# Now runnning episode:1321
# Total run time so far is: 780.6684532165527
# For episode 1321 the length is: 116
#
# Copying variables at episode 1325
# Copying variables at episode 1330
# Copying variables at episode 1335
# Copying variables at episode 1340
# Now runnning episode:1341
# Total run time so far is: 787.1328301429749
# For episode 1341 the length is: 105
#
# Copying variables at episode 1345
# Copying variables at episode 1350
# Copying variables at episode 1355
# Copying variables at episode 1360
# Now runnning episode:1361
# Total run time so far is: 792.7620003223419
# For episode 1361 the length is: 118
#
# Copying variables at episode 1365
# Copying variables at episode 1370
# Copying variables at episode 1375
# Copying variables at episode 1380
# Now runnning episode:1381
# Total run time so far is: 799.1369044780731
# For episode 1381 the length is: 122
#
# Copying variables at episode 1385
# Copying variables at episode 1390
# Copying variables at episode 1395
# Copying variables at episode 1400
# Now runnning episode:1401
# Total run time so far is: 806.561092376709
# For episode 1401 the length is: 258
#
# Copying variables at episode 1405
# Copying variables at episode 1410
# Copying variables at episode 1415
# Copying variables at episode 1420
# Now runnning episode:1421
# Total run time so far is: 816.0103962421417
# For episode 1421 the length is: 184
#
# Copying variables at episode 1425
# Copying variables at episode 1430
# Copying variables at episode 1435
# Copying variables at episode 1440
# Now runnning episode:1441
# Total run time so far is: 824.8828876018524
# For episode 1441 the length is: 196
#
# Copying variables at episode 1445
# Copying variables at episode 1450
# Copying variables at episode 1455
# Copying variables at episode 1460
# Now runnning episode:1461
# Total run time so far is: 835.7917685508728
# For episode 1461 the length is: 207
#
# Copying variables at episode 1465
# Copying variables at episode 1470
# Copying variables at episode 1475
# Copying variables at episode 1480
# Now runnning episode:1481
# Total run time so far is: 850.8794815540314
# For episode 1481 the length is: 300
#
# Copying variables at episode 1485
# Copying variables at episode 1490
# Copying variables at episode 1495
# Copying variables at episode 1500
# Now runnning episode:1501
# Total run time so far is: 871.8011503219604
# For episode 1501 the length is: 300
#
# Copying variables at episode 1505
# Copying variables at episode 1510
# Copying variables at episode 1515
# Copying variables at episode 1520
# Now runnning episode:1521
# Total run time so far is: 882.2386891841888
# For episode 1521 the length is: 149
#
# Copying variables at episode 1525
# Copying variables at episode 1530
# Copying variables at episode 1535
# Copying variables at episode 1540
# Now runnning episode:1541
# Total run time so far is: 891.1601209640503
# For episode 1541 the length is: 300
#
# Copying variables at episode 1545
# Copying variables at episode 1550
# Copying variables at episode 1555
# Copying variables at episode 1560
# Now runnning episode:1561
# Total run time so far is: 903.864061832428
# For episode 1561 the length is: 300
#
# Copying variables at episode 1565
# Copying variables at episode 1570
# Copying variables at episode 1575
# Copying variables at episode 1580
# Now runnning episode:1581
# Total run time so far is: 920.1996831893921
# For episode 1581 the length is: 300
#
# Copying variables at episode 1585
# Copying variables at episode 1590
# Copying variables at episode 1595
# Copying variables at episode 1600
# Now runnning episode:1601
# Total run time so far is: 937.66938996315
# For episode 1601 the length is: 300
#
# Copying variables at episode 1605
# Copying variables at episode 1610
# Copying variables at episode 1615
# Copying variables at episode 1620
# Now runnning episode:1621
# Total run time so far is: 949.7179701328278
# For episode 1621 the length is: 300
#
# Copying variables at episode 1625
# Copying variables at episode 1630
# Copying variables at episode 1635
# Copying variables at episode 1640
# Now runnning episode:1641
# Total run time so far is: 969.9833600521088
# For episode 1641 the length is: 165
#
# Copying variables at episode 1645
# Copying variables at episode 1650
# Copying variables at episode 1655
# Copying variables at episode 1660
# Now runnning episode:1661
# Total run time so far is: 986.6675057411194
# For episode 1661 the length is: 294
#
# Copying variables at episode 1665
# Copying variables at episode 1670
# Copying variables at episode 1675
# Copying variables at episode 1680
# Now runnning episode:1681
# Total run time so far is: 1006.0738956928253
# For episode 1681 the length is: 300
#
# Copying variables at episode 1685
# Copying variables at episode 1690
# Copying variables at episode 1695
# Copying variables at episode 1700
# Now runnning episode:1701
# Total run time so far is: 1018.6981077194214
# For episode 1701 the length is: 129
#
# Copying variables at episode 1705
# Copying variables at episode 1710
# Copying variables at episode 1715
# Copying variables at episode 1720
# Now runnning episode:1721
# Total run time so far is: 1029.365160226822
# For episode 1721 the length is: 228
#
# Copying variables at episode 1725
# Copying variables at episode 1730
# Copying variables at episode 1735
# Copying variables at episode 1740
# Now runnning episode:1741
# Total run time so far is: 1044.198941230774
# For episode 1741 the length is: 103
#
# Copying variables at episode 1745
# Copying variables at episode 1750
# Copying variables at episode 1755
# Copying variables at episode 1760
# Now runnning episode:1761
# Total run time so far is: 1050.333244085312
# For episode 1761 the length is: 126
#
# Copying variables at episode 1765
# Copying variables at episode 1770
# Copying variables at episode 1775
# Copying variables at episode 1780
# Now runnning episode:1781
# Total run time so far is: 1057.7307465076447
# For episode 1781 the length is: 127
#
# Copying variables at episode 1785
# Copying variables at episode 1790
# Copying variables at episode 1795
# Copying variables at episode 1800
# Now runnning episode:1801
# Total run time so far is: 1066.05686211586
# For episode 1801 the length is: 130
#
# Copying variables at episode 1805
# Copying variables at episode 1810
# Copying variables at episode 1815
# Copying variables at episode 1820
# Now runnning episode:1821
# Total run time so far is: 1077.1433126926422
# For episode 1821 the length is: 125
#
# Copying variables at episode 1825
# Copying variables at episode 1830
# Copying variables at episode 1835
# Copying variables at episode 1840
# Now runnning episode:1841
# Total run time so far is: 1090.0866153240204
# For episode 1841 the length is: 300
#
# Copying variables at episode 1845
# Copying variables at episode 1850
# Copying variables at episode 1855
# Copying variables at episode 1860
# Now runnning episode:1861
# Total run time so far is: 1099.661623954773
# For episode 1861 the length is: 174
#
# Copying variables at episode 1865
# Copying variables at episode 1870
# Copying variables at episode 1875
# Copying variables at episode 1880
# Now runnning episode:1881
# Total run time so far is: 1113.5222039222717
# For episode 1881 the length is: 159
#
# Copying variables at episode 1885
# Copying variables at episode 1890
# Copying variables at episode 1895
# Copying variables at episode 1900
# Now runnning episode:1901
# Total run time so far is: 1123.159514427185
# For episode 1901 the length is: 134
#
# Copying variables at episode 1905
# Copying variables at episode 1910
# Copying variables at episode 1915
# Copying variables at episode 1920
# Now runnning episode:1921
# Total run time so far is: 1133.40123128891
# For episode 1921 the length is: 211
#
# Copying variables at episode 1925
# Copying variables at episode 1930
# Copying variables at episode 1935
# Copying variables at episode 1940
# Now runnning episode:1941
# Total run time so far is: 1144.0536007881165
# For episode 1941 the length is: 112
#
# Copying variables at episode 1945
# Copying variables at episode 1950
# Copying variables at episode 1955
# Copying variables at episode 1960
# Now runnning episode:1961
# Total run time so far is: 1152.9698095321655
# For episode 1961 the length is: 168
#
# Copying variables at episode 1965
# Copying variables at episode 1970
# Copying variables at episode 1975
# Copying variables at episode 1980
# Now runnning episode:1981
# Total run time so far is: 1165.1528351306915
# For episode 1981 the length is: 176
#
# Copying variables at episode 1985
# Copying variables at episode 1990
# Copying variables at episode 1995
# Saving model...
# Total run time is: 1184.834320783615

# %%
import pandas as pd
df = pd.read_csv(csv_file)

# %%
saved_data
# Out:
# array([[ 12.6       ,  -0.89013378,   0.04656745]])

# %%
sum(i >= 200 for i in saved_data[:,0])
# Out:
# 51

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t = np.linspace(0,n_episodes-1,n_episodes/freq)
fig = plt.figure()
print(freq)
plt.plot(t,saved_data[:,0],'b')# plotting t,a separately 

fig.suptitle('Length of Episodes with SARSA', fontsize=20)
legend = plt.legend(loc='lower right', shadow=True)
plt.xlabel('Episode', fontsize=18)
plt.ylabel('length', fontsize=16)
plt.show()
#fig.savefig('./results/pics/A8_lengths_p.jpg')
# Out:
# 20.0

# %%
t = np.linspace(0,n_episodes-1,n_episodes/freq)
fig = plt.figure()
print(freq)
plt.plot(t,saved_data[:,1],'b')# plotting t,a separately 

fig.suptitle('Return of Episode with SARSA', fontsize=20)
legend = plt.legend(loc='lower right', shadow=True)
plt.xlabel('Episode', fontsize=18)
plt.ylabel('Return', fontsize=16)
plt.show()
fig.savefig('./results/pics/A8_returns.jpg')
# Out:
# 20.0

# %%
t = np.linspace(0,n_episodes-1,n_episodes/freq)
fig = plt.figure()
plt.plot(t,saved_data[:,2],'b')# plotting t,a separately 

fig.suptitle('Loss of Episode with SARSA ', fontsize=20)
legend = plt.legend(loc='lower right', shadow=True)
plt.xlabel('Episode', fontsize=18)
plt.ylabel('Loss', fontsize=16)
plt.show()
fig.savefig('./results/pics/A8_loss.jpg')

# %% [markdown]
# # Load Model
# Load the model of the best learning rate. Output the Average return and episode length

# %%
alpha = 0.001
file_name = "A8_large%i.ckpt" %(int(alpha*100000))
save_MDir = 'new_models/A8/'
save_model = os.path.join(save_MDir,file_name)
init = tf.global_variables_initializer()
print(save_model)
# Out:
# new_models/A8/A8_large100.ckpt

# %%
def test_epoch(sess, test_episodes):   
    e_length = []
    e_return = []
    av_len = []
    av_ret = []
    for _ in range(test_episodes):
        s = env.reset()
        
        for t in range(300):
            this_q = sess.run(q, feed_dict={state: s.reshape(1, 4)})
            #ac_greedily
            a = np.argmax(this_q)

            s_prime, rwd, done, info = env.step(a)

            if done:
                e_length.append(t+1)
                e_return.append(-1 * discount**t)
                break
            s = s_prime

    #av_len.append(np.mean(np.array(episode_length)))
    #av_ret.append(np.mean(np.array(episode_return)))
    return e_length, e_return

# %%
def get_placeholders():
    state = tf.placeholder("float", [None, 4], name = 'state')
    action = tf.placeholder(tf.int32, [None, 2], name = 'actions')
    next_state = tf.placeholder("float", [None, 4], name = 'next_states')
    reward = tf.placeholder("float", [None, 1], 'rewards')
    target = tf.placeholder("float", [None,1],'target')
    return state, action, next_state, reward, target

# %%
tf.reset_default_graph()
env = gym.make('CartPole-v0')
env._max_episode_steps = 300

discount = 0.99

state, action, next_state, reward,target = get_placeholders()
optimize,q,loss = get_q_optimize2(state, next_state,action, alpha, reward, discount)
init  = tf.global_variables_initializer()
test_episodes = 50
"""---------------- restore model after training  --------------------------"""
# restore model and calculate mean length and return over n_test episodes
with tf.Session() as sess:
    saver = tf.train.Saver()
    sess.run(init)
    print(save_model)
    saver.restore(sess = sess, save_path= save_model)
    print("Restored values for learning rate: ",alpha)
    restored_length, restored_return = test_epoch(sess,50)
    print('The average length of episode is: {} with std: {} '.format(np.mean(restored_length),np.std(restored_length)))
    print('The average return of episode is: {} with std: {} '.format(np.mean(restored_return),np.std(restored_return)))
# Out:
# [2017-04-08 14:49:45,409] Making new env: CartPole-v0
# new_models/A8/A8_large100.ckpt
# Restored values for learning rate:  0.001
# The average length of episode is: 297.1 with std: 11.703418304068261
# The average return of episode is: -0.05142893491129464 with std: 0.00804832577107489
